# %% [markdown]
# ### **1.1. Get the list of Michelin restaurants**
# You should begin by compiling a list of restaurants to include in your document corpus. Specifically, you will focus on web scraping the Michelin Restaurants in Italy. Your task is to collect the URL associated with each restaurant in this list. The output of this step should be a .txt file where each line contains a single restaurant’s URL. By the end, you should have approximately 2,000 restaurants on your list. The number changes daily, so some groups might have different number of restaurants.

# %%
import requests 
from bs4 import BeautifulSoup 
import os
import requests
import time
import json
import pandas as pd
from geopy.geocoders import Nominatim
from tqdm import tqdm 
from folium import Marker
from folium import Map
import folium
from folium.plugins import HeatMap, Fullscreen
import numpy as np

# %%
import requests
from bs4 import BeautifulSoup

def get_restaurant_urls(base_url, num_pages=100):
    urls = set()  # Store unique URLs

    for page in range(1, num_pages + 1):
        page_url = f"{base_url}/page/{page}"
        response = requests.get(page_url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find all <a> tags with class 'link'
            for link in soup.find_all('a', class_='link'):
                href = link.get('href')
                
                # Only add URLs containing "/restaurant/"
                if href and '/restaurant/' in href:
                    urls.add(f"https://guide.michelin.com{href}")
        else:
            print(f"Page {page} could not be loaded, please check.")  # Notify if a page fails to load

    return list(urls)

# Print and save URLs
urls = get_restaurant_urls('https://guide.michelin.com/en/it/restaurants', num_pages=100)

if urls:
    with open('restaurants_urls.txt', 'w') as file:
        for url in urls:
            file.write(f"{url}\n")
    print("Restaurant URLs saved successfully!")
else:
    print("No URLs found, please check the HTML structure.")  # Notify if no URLs are found
# Out:
# Restaurant URLs saved successfully!

# %% [markdown]
# ### -1.2. Crawl Michelin restaurant pages
# Once you have all the URLs on the list, you should:
#
# Download the HTML corresponding to each of the collected URLs.
# After collecting each page, immediately save its HTML in a file. This way, if your program stops for any reason, you will not lose the data collected up to the stopping point.
# Organize the downloaded HTML pages into folders. Each folder will contain the HTML of the restaurants from page 1, page 2, ... of the Michelin restaurant list.
# Tip: Due to the large number of pages to download, consider using methods that can help shorten the process. If you employed a particular process or approach, kindly describe it.

# %%
# Read the URL list file
with open('restaurants_urls.txt', 'r') as file:
    urls = file.readlines()

# Function to create folders and download HTML files
def download_html_pages(urls, base_folder='michelin_pages'):
    # Create the base folder if it doesn't exist
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)

    for i, url in enumerate(urls):
        url = url.strip()
        page_number = (i // 20) + 1  # Each 20 restaurants belong to one page
        folder_path = os.path.join(base_folder, f'page_{page_number}')
        
        # Create the folder for each page if it doesn't exist
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        
        # Define the file path for each restaurant's HTML file
        file_path = os.path.join(folder_path, f'restaurant_{i+1}.html')
        
        # If the file already exists, skip downloading it
        if os.path.exists(file_path):
            print(f"{file_path} already exists, skipping.")
            continue

        try:
            # Download the HTML content of the restaurant page
            response = requests.get(url)
            if response.status_code == 200:
                with open(file_path, 'w', encoding='utf-8') as html_file:
                    html_file.write(response.text)
                print(f"{file_path} downloaded successfully.")
            else:
                print(f"{url} could not be downloaded, status code: {response.status_code}")
        except Exception as e:
            print(f"An error occurred while downloading {url}: {e}")
        
        time.sleep(1)  # Wait to prevent too fast downloads

# Download HTML pages
download_html_pages(urls)
# Out:
# michelin_pages/page_1/restaurant_1.html already exists, skipping.
# michelin_pages/page_1/restaurant_2.html already exists, skipping.
# michelin_pages/page_1/restaurant_3.html already exists, skipping.
# michelin_pages/page_1/restaurant_4.html already exists, skipping.
# michelin_pages/page_1/restaurant_5.html already exists, skipping.
# michelin_pages/page_1/restaurant_6.html already exists, skipping.
# michelin_pages/page_1/restaurant_7.html already exists, skipping.
# michelin_pages/page_1/restaurant_8.html already exists, skipping.
# michelin_pages/page_1/restaurant_9.html already exists, skipping.
# michelin_pages/page_1/restaurant_10.html already exists, skipping.
# michelin_pages/page_1/restaurant_11.html already exists, skipping.
# michelin_pages/page_1/restaurant_12.html already exists, skipping.
# michelin_pages/page_1/restaurant_13.html already exists, skipping.
# michelin_pages/page_1/restaurant_14.html already exists, skipping.
# michelin_pages/page_1/restaurant_15.html already exists, skipping.
# michelin_pages/page_1/restaurant_16.html already exists, skipping.
# michelin_pages/page_1/restaurant_17.html already exists, skipping.
# michelin_pages/page_1/restaurant_18.html already exists, skipping.
# michelin_pages/page_1/restaurant_19.html already exists, skipping.
# michelin_pages/page_1/restaurant_20.html already exists, skipping.
# michelin_pages/page_2/restaurant_21.html already exists, skipping.
# michelin_pages/page_2/restaurant_22.html already exists, skipping.
# michelin_pages/page_2/restaurant_23.html already exists, skipping.
# michelin_pages/page_2/restaurant_24.html already exists, skipping.
# michelin_pages/page_2/restaurant_25.html already exists, skipping.
# michelin_pages/page_2/restaurant_26.html already exists, skipping.
# michelin_pages/page_2/restaurant_27.html already exists, skipping.
# michelin_pages/page_2/restaurant_28.html already exists, skipping.
# michelin_pages/page_2/restaurant_29.html already exists, skipping.
# michelin_pages/page_2/restaurant_30.html already exists, skipping.
# michelin_pages/page_2/restaurant_31.html already exists, skipping.
# michelin_pages/page_2/restaurant_32.html already exists, skipping.
# michelin_pages/page_2/restaurant_33.html already exists, skipping.
# michelin_pages/page_2/restaurant_34.html already exists, skipping.
# michelin_pages/page_2/restaurant_35.html already exists, skipping.
# michelin_pages/page_2/restaurant_36.html already exists, skipping.
# michelin_pages/page_2/restaurant_37.html already exists, skipping.
# michelin_pages/page_2/restaurant_38.html already exists, skipping.
# michelin_pages/page_2/restaurant_39.html already exists, skipping.
# michelin_pages/page_2/restaurant_40.html already exists, skipping.
# michelin_pages/page_3/restaurant_41.html already exists, skipping.
# michelin_pages/page_3/restaurant_42.html already exists, skipping.
# michelin_pages/page_3/restaurant_43.html already exists, skipping.
# michelin_pages/page_3/restaurant_44.html already exists, skipping.
# michelin_pages/page_3/restaurant_45.html already exists, skipping.
# michelin_pages/page_3/restaurant_46.html already exists, skipping.
# michelin_pages/page_3/restaurant_47.html already exists, skipping.
# michelin_pages/page_3/restaurant_48.html already exists, skipping.
# michelin_pages/page_3/restaurant_49.html already exists, skipping.
# michelin_pages/page_3/restaurant_50.html already exists, skipping.
# michelin_pages/page_3/restaurant_51.html already exists, skipping.
# michelin_pages/page_3/restaurant_52.html already exists, skipping.
# michelin_pages/page_3/restaurant_53.html already exists, skipping.
# michelin_pages/page_3/restaurant_54.html already exists, skipping.
# michelin_pages/page_3/restaurant_55.html already exists, skipping.
# michelin_pages/page_3/restaurant_56.html already exists, skipping.
# michelin_pages/page_3/restaurant_57.html already exists, skipping.
# michelin_pages/page_3/restaurant_58.html already exists, skipping.
# michelin_pages/page_3/restaurant_59.html already exists, skipping.
# michelin_pages/page_3/restaurant_60.html already exists, skipping.
# michelin_pages/page_4/restaurant_61.html already exists, skipping.
# michelin_pages/page_4/restaurant_62.html already exists, skipping.
# michelin_pages/page_4/restaurant_63.html already exists, skipping.
# michelin_pages/page_4/restaurant_64.html already exists, skipping.
# michelin_pages/page_4/restaurant_65.html already exists, skipping.
# michelin_pages/page_4/restaurant_66.html already exists, skipping.
# michelin_pages/page_4/restaurant_67.html already exists, skipping.
# michelin_pages/page_4/restaurant_68.html already exists, skipping.
# michelin_pages/page_4/restaurant_69.html already exists, skipping.
# michelin_pages/page_4/restaurant_70.html already exists, skipping.
# michelin_pages/page_4/restaurant_71.html already exists, skipping.
# michelin_pages/page_4/restaurant_72.html already exists, skipping.
# michelin_pages/page_4/restaurant_73.html already exists, skipping.
# michelin_pages/page_4/restaurant_74.html already exists, skipping.
# michelin_pages/page_4/restaurant_75.html already exists, skipping.
# michelin_pages/page_4/restaurant_76.html already exists, skipping.
# michelin_pages/page_4/restaurant_77.html already exists, skipping.
# michelin_pages/page_4/restaurant_78.html already exists, skipping.
# michelin_pages/page_4/restaurant_79.html already exists, skipping.
# michelin_pages/page_4/restaurant_80.html already exists, skipping.
# michelin_pages/page_5/restaurant_81.html already exists, skipping.
# michelin_pages/page_5/restaurant_82.html already exists, skipping.
# michelin_pages/page_5/restaurant_83.html already exists, skipping.
# michelin_pages/page_5/restaurant_84.html already exists, skipping.
# michelin_pages/page_5/restaurant_85.html already exists, skipping.
# michelin_pages/page_5/restaurant_86.html already exists, skipping.
# michelin_pages/page_5/restaurant_87.html already exists, skipping.
# michelin_pages/page_5/restaurant_88.html already exists, skipping.
# michelin_pages/page_5/restaurant_89.html already exists, skipping.
# michelin_pages/page_5/restaurant_90.html already exists, skipping.
# michelin_pages/page_5/restaurant_91.html already exists, skipping.
# michelin_pages/page_5/restaurant_92.html already exists, skipping.
# michelin_pages/page_5/restaurant_93.html already exists, skipping.
# michelin_pages/page_5/restaurant_94.html already exists, skipping.
# michelin_pages/page_5/restaurant_95.html already exists, skipping.
# michelin_pages/page_5/restaurant_96.html already exists, skipping.
# michelin_pages/page_5/restaurant_97.html already exists, skipping.
# michelin_pages/page_5/restaurant_98.html already exists, skipping.
# michelin_pages/page_5/restaurant_99.html already exists, skipping.
# michelin_pages/page_5/restaurant_100.html already exists, skipping.
# michelin_pages/page_6/restaurant_101.html already exists, skipping.
# michelin_pages/page_6/restaurant_102.html already exists, skipping.
# michelin_pages/page_6/restaurant_103.html already exists, skipping.
# michelin_pages/page_6/restaurant_104.html already exists, skipping.
# michelin_pages/page_6/restaurant_105.html already exists, skipping.
# michelin_pages/page_6/restaurant_106.html already exists, skipping.
# michelin_pages/page_6/restaurant_107.html already exists, skipping.
# michelin_pages/page_6/restaurant_108.html already exists, skipping.
# michelin_pages/page_6/restaurant_109.html already exists, skipping.
# michelin_pages/page_6/restaurant_110.html already exists, skipping.
# michelin_pages/page_6/restaurant_111.html already exists, skipping.
# michelin_pages/page_6/restaurant_112.html already exists, skipping.
# michelin_pages/page_6/restaurant_113.html already exists, skipping.
# michelin_pages/page_6/restaurant_114.html already exists, skipping.
# michelin_pages/page_6/restaurant_115.html already exists, skipping.
# michelin_pages/page_6/restaurant_116.html already exists, skipping.
# michelin_pages/page_6/restaurant_117.html already exists, skipping.
# michelin_pages/page_6/restaurant_118.html already exists, skipping.
# michelin_pages/page_6/restaurant_119.html already exists, skipping.
# michelin_pages/page_6/restaurant_120.html already exists, skipping.
# michelin_pages/page_7/restaurant_121.html already exists, skipping.
# michelin_pages/page_7/restaurant_122.html already exists, skipping.
# michelin_pages/page_7/restaurant_123.html already exists, skipping.
# michelin_pages/page_7/restaurant_124.html already exists, skipping.
# michelin_pages/page_7/restaurant_125.html already exists, skipping.
# michelin_pages/page_7/restaurant_126.html already exists, skipping.
# michelin_pages/page_7/restaurant_127.html already exists, skipping.
# michelin_pages/page_7/restaurant_128.html already exists, skipping.
# michelin_pages/page_7/restaurant_129.html already exists, skipping.
# michelin_pages/page_7/restaurant_130.html already exists, skipping.
# michelin_pages/page_7/restaurant_131.html already exists, skipping.
# michelin_pages/page_7/restaurant_132.html already exists, skipping.
# michelin_pages/page_7/restaurant_133.html already exists, skipping.
# michelin_pages/page_7/restaurant_134.html already exists, skipping.
# michelin_pages/page_7/restaurant_135.html already exists, skipping.
# michelin_pages/page_7/restaurant_136.html already exists, skipping.
# michelin_pages/page_7/restaurant_137.html already exists, skipping.
# michelin_pages/page_7/restaurant_138.html already exists, skipping.
# michelin_pages/page_7/restaurant_139.html already exists, skipping.
# michelin_pages/page_7/restaurant_140.html already exists, skipping.
# michelin_pages/page_8/restaurant_141.html already exists, skipping.
# michelin_pages/page_8/restaurant_142.html already exists, skipping.
# michelin_pages/page_8/restaurant_143.html already exists, skipping.
# michelin_pages/page_8/restaurant_144.html already exists, skipping.
# michelin_pages/page_8/restaurant_145.html already exists, skipping.
# michelin_pages/page_8/restaurant_146.html already exists, skipping.
# michelin_pages/page_8/restaurant_147.html already exists, skipping.
# michelin_pages/page_8/restaurant_148.html already exists, skipping.
# michelin_pages/page_8/restaurant_149.html already exists, skipping.
# michelin_pages/page_8/restaurant_150.html already exists, skipping.
# michelin_pages/page_8/restaurant_151.html already exists, skipping.
# michelin_pages/page_8/restaurant_152.html already exists, skipping.
# michelin_pages/page_8/restaurant_153.html already exists, skipping.
# michelin_pages/page_8/restaurant_154.html already exists, skipping.
# michelin_pages/page_8/restaurant_155.html already exists, skipping.
# michelin_pages/page_8/restaurant_156.html already exists, skipping.
# michelin_pages/page_8/restaurant_157.html already exists, skipping.
# michelin_pages/page_8/restaurant_158.html already exists, skipping.
# michelin_pages/page_8/restaurant_159.html already exists, skipping.
# michelin_pages/page_8/restaurant_160.html already exists, skipping.
# michelin_pages/page_9/restaurant_161.html already exists, skipping.
# michelin_pages/page_9/restaurant_162.html already exists, skipping.
# michelin_pages/page_9/restaurant_163.html already exists, skipping.
# michelin_pages/page_9/restaurant_164.html already exists, skipping.
# michelin_pages/page_9/restaurant_165.html already exists, skipping.
# michelin_pages/page_9/restaurant_166.html already exists, skipping.
# michelin_pages/page_9/restaurant_167.html already exists, skipping.
# michelin_pages/page_9/restaurant_168.html already exists, skipping.
# michelin_pages/page_9/restaurant_169.html already exists, skipping.
# michelin_pages/page_9/restaurant_170.html already exists, skipping.
# michelin_pages/page_9/restaurant_171.html already exists, skipping.
# michelin_pages/page_9/restaurant_172.html already exists, skipping.
# michelin_pages/page_9/restaurant_173.html already exists, skipping.
# michelin_pages/page_9/restaurant_174.html already exists, skipping.
# michelin_pages/page_9/restaurant_175.html already exists, skipping.
# michelin_pages/page_9/restaurant_176.html already exists, skipping.
# michelin_pages/page_9/restaurant_177.html already exists, skipping.
# michelin_pages/page_9/restaurant_178.html already exists, skipping.
# michelin_pages/page_9/restaurant_179.html already exists, skipping.
# michelin_pages/page_9/restaurant_180.html already exists, skipping.
# michelin_pages/page_10/restaurant_181.html already exists, skipping.
# michelin_pages/page_10/restaurant_182.html already exists, skipping.
# michelin_pages/page_10/restaurant_183.html already exists, skipping.
# michelin_pages/page_10/restaurant_184.html already exists, skipping.
# michelin_pages/page_10/restaurant_185.html already exists, skipping.
# michelin_pages/page_10/restaurant_186.html already exists, skipping.
# michelin_pages/page_10/restaurant_187.html already exists, skipping.
# michelin_pages/page_10/restaurant_188.html already exists, skipping.
# michelin_pages/page_10/restaurant_189.html already exists, skipping.
# michelin_pages/page_10/restaurant_190.html already exists, skipping.
# michelin_pages/page_10/restaurant_191.html already exists, skipping.
# michelin_pages/page_10/restaurant_192.html already exists, skipping.
# michelin_pages/page_10/restaurant_193.html already exists, skipping.
# michelin_pages/page_10/restaurant_194.html already exists, skipping.
# michelin_pages/page_10/restaurant_195.html already exists, skipping.
# michelin_pages/page_10/restaurant_196.html already exists, skipping.
# michelin_pages/page_10/restaurant_197.html already exists, skipping.
# michelin_pages/page_10/restaurant_198.html already exists, skipping.
# michelin_pages/page_10/restaurant_199.html already exists, skipping.
# michelin_pages/page_10/restaurant_200.html already exists, skipping.
# michelin_pages/page_11/restaurant_201.html already exists, skipping.
# michelin_pages/page_11/restaurant_202.html already exists, skipping.
# michelin_pages/page_11/restaurant_203.html already exists, skipping.
# michelin_pages/page_11/restaurant_204.html already exists, skipping.
# michelin_pages/page_11/restaurant_205.html already exists, skipping.
# michelin_pages/page_11/restaurant_206.html already exists, skipping.
# michelin_pages/page_11/restaurant_207.html already exists, skipping.
# michelin_pages/page_11/restaurant_208.html already exists, skipping.
# michelin_pages/page_11/restaurant_209.html already exists, skipping.
# michelin_pages/page_11/restaurant_210.html already exists, skipping.
# michelin_pages/page_11/restaurant_211.html already exists, skipping.
# michelin_pages/page_11/restaurant_212.html already exists, skipping.
# michelin_pages/page_11/restaurant_213.html already exists, skipping.
# michelin_pages/page_11/restaurant_214.html already exists, skipping.
# michelin_pages/page_11/restaurant_215.html already exists, skipping.
# michelin_pages/page_11/restaurant_216.html already exists, skipping.
# michelin_pages/page_11/restaurant_217.html already exists, skipping.
# michelin_pages/page_11/restaurant_218.html already exists, skipping.
# michelin_pages/page_11/restaurant_219.html already exists, skipping.
# michelin_pages/page_11/restaurant_220.html already exists, skipping.
# michelin_pages/page_12/restaurant_221.html already exists, skipping.
# michelin_pages/page_12/restaurant_222.html already exists, skipping.
# michelin_pages/page_12/restaurant_223.html already exists, skipping.
# michelin_pages/page_12/restaurant_224.html already exists, skipping.
# michelin_pages/page_12/restaurant_225.html already exists, skipping.
# michelin_pages/page_12/restaurant_226.html already exists, skipping.
# michelin_pages/page_12/restaurant_227.html already exists, skipping.
# michelin_pages/page_12/restaurant_228.html already exists, skipping.
# michelin_pages/page_12/restaurant_229.html already exists, skipping.
# michelin_pages/page_12/restaurant_230.html already exists, skipping.
# michelin_pages/page_12/restaurant_231.html already exists, skipping.
# michelin_pages/page_12/restaurant_232.html already exists, skipping.
# michelin_pages/page_12/restaurant_233.html already exists, skipping.
# michelin_pages/page_12/restaurant_234.html already exists, skipping.
# michelin_pages/page_12/restaurant_235.html already exists, skipping.
# michelin_pages/page_12/restaurant_236.html already exists, skipping.
# michelin_pages/page_12/restaurant_237.html already exists, skipping.
# michelin_pages/page_12/restaurant_238.html already exists, skipping.
# michelin_pages/page_12/restaurant_239.html already exists, skipping.
# michelin_pages/page_12/restaurant_240.html already exists, skipping.
# michelin_pages/page_13/restaurant_241.html already exists, skipping.
# michelin_pages/page_13/restaurant_242.html already exists, skipping.
# michelin_pages/page_13/restaurant_243.html already exists, skipping.
# michelin_pages/page_13/restaurant_244.html already exists, skipping.
# michelin_pages/page_13/restaurant_245.html already exists, skipping.
# michelin_pages/page_13/restaurant_246.html already exists, skipping.
# michelin_pages/page_13/restaurant_247.html already exists, skipping.
# michelin_pages/page_13/restaurant_248.html already exists, skipping.
# michelin_pages/page_13/restaurant_249.html already exists, skipping.
# michelin_pages/page_13/restaurant_250.html already exists, skipping.
# michelin_pages/page_13/restaurant_251.html already exists, skipping.
# michelin_pages/page_13/restaurant_252.html already exists, skipping.
# michelin_pages/page_13/restaurant_253.html already exists, skipping.
# michelin_pages/page_13/restaurant_254.html already exists, skipping.
# michelin_pages/page_13/restaurant_255.html already exists, skipping.
# michelin_pages/page_13/restaurant_256.html already exists, skipping.
# michelin_pages/page_13/restaurant_257.html already exists, skipping.
# michelin_pages/page_13/restaurant_258.html already exists, skipping.
# michelin_pages/page_13/restaurant_259.html already exists, skipping.
# michelin_pages/page_13/restaurant_260.html already exists, skipping.
# michelin_pages/page_14/restaurant_261.html already exists, skipping.
# michelin_pages/page_14/restaurant_262.html already exists, skipping.
# michelin_pages/page_14/restaurant_263.html already exists, skipping.
# michelin_pages/page_14/restaurant_264.html already exists, skipping.
# michelin_pages/page_14/restaurant_265.html already exists, skipping.
# michelin_pages/page_14/restaurant_266.html already exists, skipping.
# michelin_pages/page_14/restaurant_267.html already exists, skipping.
# michelin_pages/page_14/restaurant_268.html already exists, skipping.
# michelin_pages/page_14/restaurant_269.html already exists, skipping.
# michelin_pages/page_14/restaurant_270.html already exists, skipping.
# michelin_pages/page_14/restaurant_271.html already exists, skipping.
# michelin_pages/page_14/restaurant_272.html already exists, skipping.
# michelin_pages/page_14/restaurant_273.html already exists, skipping.
# michelin_pages/page_14/restaurant_274.html already exists, skipping.
# michelin_pages/page_14/restaurant_275.html already exists, skipping.
# michelin_pages/page_14/restaurant_276.html already exists, skipping.
# michelin_pages/page_14/restaurant_277.html already exists, skipping.
# michelin_pages/page_14/restaurant_278.html already exists, skipping.
# michelin_pages/page_14/restaurant_279.html already exists, skipping.
# michelin_pages/page_14/restaurant_280.html already exists, skipping.
# michelin_pages/page_15/restaurant_281.html already exists, skipping.
# michelin_pages/page_15/restaurant_282.html already exists, skipping.
# michelin_pages/page_15/restaurant_283.html already exists, skipping.
# michelin_pages/page_15/restaurant_284.html already exists, skipping.
# michelin_pages/page_15/restaurant_285.html already exists, skipping.
# michelin_pages/page_15/restaurant_286.html already exists, skipping.
# michelin_pages/page_15/restaurant_287.html already exists, skipping.
# michelin_pages/page_15/restaurant_288.html already exists, skipping.
# michelin_pages/page_15/restaurant_289.html already exists, skipping.
# michelin_pages/page_15/restaurant_290.html already exists, skipping.
# michelin_pages/page_15/restaurant_291.html already exists, skipping.
# michelin_pages/page_15/restaurant_292.html already exists, skipping.
# michelin_pages/page_15/restaurant_293.html already exists, skipping.
# michelin_pages/page_15/restaurant_294.html already exists, skipping.
# michelin_pages/page_15/restaurant_295.html already exists, skipping.
# michelin_pages/page_15/restaurant_296.html already exists, skipping.
# michelin_pages/page_15/restaurant_297.html already exists, skipping.
# michelin_pages/page_15/restaurant_298.html already exists, skipping.
# michelin_pages/page_15/restaurant_299.html already exists, skipping.
# michelin_pages/page_15/restaurant_300.html already exists, skipping.
# michelin_pages/page_16/restaurant_301.html already exists, skipping.
# michelin_pages/page_16/restaurant_302.html already exists, skipping.
# michelin_pages/page_16/restaurant_303.html already exists, skipping.
# michelin_pages/page_16/restaurant_304.html already exists, skipping.
# michelin_pages/page_16/restaurant_305.html already exists, skipping.
# michelin_pages/page_16/restaurant_306.html already exists, skipping.
# michelin_pages/page_16/restaurant_307.html already exists, skipping.
# michelin_pages/page_16/restaurant_308.html already exists, skipping.
# michelin_pages/page_16/restaurant_309.html already exists, skipping.
# michelin_pages/page_16/restaurant_310.html already exists, skipping.
# michelin_pages/page_16/restaurant_311.html already exists, skipping.
# michelin_pages/page_16/restaurant_312.html already exists, skipping.
# michelin_pages/page_16/restaurant_313.html already exists, skipping.
# michelin_pages/page_16/restaurant_314.html already exists, skipping.
# michelin_pages/page_16/restaurant_315.html already exists, skipping.
# michelin_pages/page_16/restaurant_316.html already exists, skipping.
# michelin_pages/page_16/restaurant_317.html already exists, skipping.
# michelin_pages/page_16/restaurant_318.html already exists, skipping.
# michelin_pages/page_16/restaurant_319.html already exists, skipping.
# michelin_pages/page_16/restaurant_320.html already exists, skipping.
# michelin_pages/page_17/restaurant_321.html already exists, skipping.
# michelin_pages/page_17/restaurant_322.html already exists, skipping.
# michelin_pages/page_17/restaurant_323.html already exists, skipping.
# michelin_pages/page_17/restaurant_324.html already exists, skipping.
# michelin_pages/page_17/restaurant_325.html already exists, skipping.
# michelin_pages/page_17/restaurant_326.html already exists, skipping.
# michelin_pages/page_17/restaurant_327.html already exists, skipping.
# michelin_pages/page_17/restaurant_328.html already exists, skipping.
# michelin_pages/page_17/restaurant_329.html already exists, skipping.
# michelin_pages/page_17/restaurant_330.html already exists, skipping.
# michelin_pages/page_17/restaurant_331.html already exists, skipping.
# michelin_pages/page_17/restaurant_332.html already exists, skipping.
# michelin_pages/page_17/restaurant_333.html already exists, skipping.
# michelin_pages/page_17/restaurant_334.html already exists, skipping.
# michelin_pages/page_17/restaurant_335.html already exists, skipping.
# michelin_pages/page_17/restaurant_336.html already exists, skipping.
# michelin_pages/page_17/restaurant_337.html already exists, skipping.
# michelin_pages/page_17/restaurant_338.html already exists, skipping.
# michelin_pages/page_17/restaurant_339.html already exists, skipping.
# michelin_pages/page_17/restaurant_340.html already exists, skipping.
# michelin_pages/page_18/restaurant_341.html already exists, skipping.
# michelin_pages/page_18/restaurant_342.html already exists, skipping.
# michelin_pages/page_18/restaurant_343.html already exists, skipping.
# michelin_pages/page_18/restaurant_344.html already exists, skipping.
# michelin_pages/page_18/restaurant_345.html already exists, skipping.
# michelin_pages/page_18/restaurant_346.html already exists, skipping.
# michelin_pages/page_18/restaurant_347.html already exists, skipping.
# michelin_pages/page_18/restaurant_348.html already exists, skipping.
# michelin_pages/page_18/restaurant_349.html already exists, skipping.
# michelin_pages/page_18/restaurant_350.html already exists, skipping.
# michelin_pages/page_18/restaurant_351.html already exists, skipping.
# michelin_pages/page_18/restaurant_352.html already exists, skipping.
# michelin_pages/page_18/restaurant_353.html already exists, skipping.
# michelin_pages/page_18/restaurant_354.html already exists, skipping.
# michelin_pages/page_18/restaurant_355.html already exists, skipping.
# michelin_pages/page_18/restaurant_356.html already exists, skipping.
# michelin_pages/page_18/restaurant_357.html already exists, skipping.
# michelin_pages/page_18/restaurant_358.html already exists, skipping.
# michelin_pages/page_18/restaurant_359.html already exists, skipping.
# michelin_pages/page_18/restaurant_360.html already exists, skipping.
# michelin_pages/page_19/restaurant_361.html already exists, skipping.
# michelin_pages/page_19/restaurant_362.html already exists, skipping.
# michelin_pages/page_19/restaurant_363.html already exists, skipping.
# michelin_pages/page_19/restaurant_364.html already exists, skipping.
# michelin_pages/page_19/restaurant_365.html already exists, skipping.
# michelin_pages/page_19/restaurant_366.html already exists, skipping.
# michelin_pages/page_19/restaurant_367.html already exists, skipping.
# michelin_pages/page_19/restaurant_368.html already exists, skipping.
# michelin_pages/page_19/restaurant_369.html already exists, skipping.
# michelin_pages/page_19/restaurant_370.html already exists, skipping.
# michelin_pages/page_19/restaurant_371.html already exists, skipping.
# michelin_pages/page_19/restaurant_372.html already exists, skipping.
# michelin_pages/page_19/restaurant_373.html already exists, skipping.
# michelin_pages/page_19/restaurant_374.html already exists, skipping.
# michelin_pages/page_19/restaurant_375.html already exists, skipping.
# michelin_pages/page_19/restaurant_376.html already exists, skipping.
# michelin_pages/page_19/restaurant_377.html already exists, skipping.
# michelin_pages/page_19/restaurant_378.html already exists, skipping.
# michelin_pages/page_19/restaurant_379.html already exists, skipping.
# michelin_pages/page_19/restaurant_380.html already exists, skipping.
# michelin_pages/page_20/restaurant_381.html already exists, skipping.
# michelin_pages/page_20/restaurant_382.html already exists, skipping.
# michelin_pages/page_20/restaurant_383.html already exists, skipping.
# michelin_pages/page_20/restaurant_384.html already exists, skipping.
# michelin_pages/page_20/restaurant_385.html already exists, skipping.
# michelin_pages/page_20/restaurant_386.html already exists, skipping.
# michelin_pages/page_20/restaurant_387.html already exists, skipping.
# michelin_pages/page_20/restaurant_388.html already exists, skipping.
# michelin_pages/page_20/restaurant_389.html already exists, skipping.
# michelin_pages/page_20/restaurant_390.html already exists, skipping.
# michelin_pages/page_20/restaurant_391.html already exists, skipping.
# michelin_pages/page_20/restaurant_392.html already exists, skipping.
# michelin_pages/page_20/restaurant_393.html already exists, skipping.
# michelin_pages/page_20/restaurant_394.html already exists, skipping.
# michelin_pages/page_20/restaurant_395.html already exists, skipping.
# michelin_pages/page_20/restaurant_396.html already exists, skipping.
# michelin_pages/page_20/restaurant_397.html already exists, skipping.
# michelin_pages/page_20/restaurant_398.html already exists, skipping.
# michelin_pages/page_20/restaurant_399.html already exists, skipping.
# michelin_pages/page_20/restaurant_400.html already exists, skipping.
# michelin_pages/page_21/restaurant_401.html already exists, skipping.
# michelin_pages/page_21/restaurant_402.html already exists, skipping.
# michelin_pages/page_21/restaurant_403.html already exists, skipping.
# michelin_pages/page_21/restaurant_404.html already exists, skipping.
# michelin_pages/page_21/restaurant_405.html already exists, skipping.
# michelin_pages/page_21/restaurant_406.html already exists, skipping.
# michelin_pages/page_21/restaurant_407.html already exists, skipping.
# michelin_pages/page_21/restaurant_408.html already exists, skipping.
# michelin_pages/page_21/restaurant_409.html already exists, skipping.
# michelin_pages/page_21/restaurant_410.html already exists, skipping.
# michelin_pages/page_21/restaurant_411.html already exists, skipping.
# michelin_pages/page_21/restaurant_412.html already exists, skipping.
# michelin_pages/page_21/restaurant_413.html already exists, skipping.
# michelin_pages/page_21/restaurant_414.html already exists, skipping.
# michelin_pages/page_21/restaurant_415.html already exists, skipping.
# michelin_pages/page_21/restaurant_416.html already exists, skipping.
# michelin_pages/page_21/restaurant_417.html already exists, skipping.
# michelin_pages/page_21/restaurant_418.html already exists, skipping.
# michelin_pages/page_21/restaurant_419.html already exists, skipping.
# michelin_pages/page_21/restaurant_420.html already exists, skipping.
# michelin_pages/page_22/restaurant_421.html already exists, skipping.
# michelin_pages/page_22/restaurant_422.html already exists, skipping.
# michelin_pages/page_22/restaurant_423.html already exists, skipping.
# michelin_pages/page_22/restaurant_424.html already exists, skipping.
# michelin_pages/page_22/restaurant_425.html already exists, skipping.
# michelin_pages/page_22/restaurant_426.html already exists, skipping.
# michelin_pages/page_22/restaurant_427.html already exists, skipping.
# michelin_pages/page_22/restaurant_428.html already exists, skipping.
# michelin_pages/page_22/restaurant_429.html already exists, skipping.
# michelin_pages/page_22/restaurant_430.html already exists, skipping.
# michelin_pages/page_22/restaurant_431.html already exists, skipping.
# michelin_pages/page_22/restaurant_432.html already exists, skipping.
# michelin_pages/page_22/restaurant_433.html already exists, skipping.
# michelin_pages/page_22/restaurant_434.html already exists, skipping.
# michelin_pages/page_22/restaurant_435.html already exists, skipping.
# michelin_pages/page_22/restaurant_436.html already exists, skipping.
# michelin_pages/page_22/restaurant_437.html already exists, skipping.
# michelin_pages/page_22/restaurant_438.html already exists, skipping.
# michelin_pages/page_22/restaurant_439.html already exists, skipping.
# michelin_pages/page_22/restaurant_440.html already exists, skipping.
# michelin_pages/page_23/restaurant_441.html already exists, skipping.
# michelin_pages/page_23/restaurant_442.html already exists, skipping.
# michelin_pages/page_23/restaurant_443.html already exists, skipping.
# michelin_pages/page_23/restaurant_444.html already exists, skipping.
# michelin_pages/page_23/restaurant_445.html already exists, skipping.
# michelin_pages/page_23/restaurant_446.html already exists, skipping.
# michelin_pages/page_23/restaurant_447.html already exists, skipping.
# michelin_pages/page_23/restaurant_448.html already exists, skipping.
# michelin_pages/page_23/restaurant_449.html already exists, skipping.
# michelin_pages/page_23/restaurant_450.html already exists, skipping.
# michelin_pages/page_23/restaurant_451.html already exists, skipping.
# michelin_pages/page_23/restaurant_452.html already exists, skipping.
# michelin_pages/page_23/restaurant_453.html already exists, skipping.
# michelin_pages/page_23/restaurant_454.html already exists, skipping.
# michelin_pages/page_23/restaurant_455.html already exists, skipping.
# michelin_pages/page_23/restaurant_456.html already exists, skipping.
# michelin_pages/page_23/restaurant_457.html already exists, skipping.
# michelin_pages/page_23/restaurant_458.html already exists, skipping.
# michelin_pages/page_23/restaurant_459.html already exists, skipping.
# michelin_pages/page_23/restaurant_460.html already exists, skipping.
# michelin_pages/page_24/restaurant_461.html already exists, skipping.
# michelin_pages/page_24/restaurant_462.html already exists, skipping.
# michelin_pages/page_24/restaurant_463.html already exists, skipping.
# michelin_pages/page_24/restaurant_464.html already exists, skipping.
# michelin_pages/page_24/restaurant_465.html already exists, skipping.
# michelin_pages/page_24/restaurant_466.html already exists, skipping.
# michelin_pages/page_24/restaurant_467.html already exists, skipping.
# michelin_pages/page_24/restaurant_468.html already exists, skipping.
# michelin_pages/page_24/restaurant_469.html already exists, skipping.
# michelin_pages/page_24/restaurant_470.html already exists, skipping.
# michelin_pages/page_24/restaurant_471.html already exists, skipping.
# michelin_pages/page_24/restaurant_472.html already exists, skipping.
# michelin_pages/page_24/restaurant_473.html already exists, skipping.
# michelin_pages/page_24/restaurant_474.html already exists, skipping.
# michelin_pages/page_24/restaurant_475.html already exists, skipping.
# michelin_pages/page_24/restaurant_476.html already exists, skipping.
# michelin_pages/page_24/restaurant_477.html already exists, skipping.
# michelin_pages/page_24/restaurant_478.html already exists, skipping.
# michelin_pages/page_24/restaurant_479.html already exists, skipping.
# michelin_pages/page_24/restaurant_480.html already exists, skipping.
# michelin_pages/page_25/restaurant_481.html already exists, skipping.
# michelin_pages/page_25/restaurant_482.html already exists, skipping.
# michelin_pages/page_25/restaurant_483.html already exists, skipping.
# michelin_pages/page_25/restaurant_484.html already exists, skipping.
# michelin_pages/page_25/restaurant_485.html already exists, skipping.
# michelin_pages/page_25/restaurant_486.html already exists, skipping.
# michelin_pages/page_25/restaurant_487.html already exists, skipping.
# michelin_pages/page_25/restaurant_488.html already exists, skipping.
# michelin_pages/page_25/restaurant_489.html already exists, skipping.
# michelin_pages/page_25/restaurant_490.html already exists, skipping.
# michelin_pages/page_25/restaurant_491.html already exists, skipping.
# michelin_pages/page_25/restaurant_492.html already exists, skipping.
# michelin_pages/page_25/restaurant_493.html already exists, skipping.
# michelin_pages/page_25/restaurant_494.html already exists, skipping.
# michelin_pages/page_25/restaurant_495.html already exists, skipping.
# michelin_pages/page_25/restaurant_496.html already exists, skipping.
# michelin_pages/page_25/restaurant_497.html already exists, skipping.
# michelin_pages/page_25/restaurant_498.html already exists, skipping.
# michelin_pages/page_25/restaurant_499.html already exists, skipping.
# michelin_pages/page_25/restaurant_500.html already exists, skipping.
# michelin_pages/page_26/restaurant_501.html already exists, skipping.
# michelin_pages/page_26/restaurant_502.html already exists, skipping.
# michelin_pages/page_26/restaurant_503.html already exists, skipping.
# michelin_pages/page_26/restaurant_504.html already exists, skipping.
# michelin_pages/page_26/restaurant_505.html already exists, skipping.
# michelin_pages/page_26/restaurant_506.html already exists, skipping.
# michelin_pages/page_26/restaurant_507.html already exists, skipping.
# michelin_pages/page_26/restaurant_508.html already exists, skipping.
# michelin_pages/page_26/restaurant_509.html already exists, skipping.
# michelin_pages/page_26/restaurant_510.html already exists, skipping.
# michelin_pages/page_26/restaurant_511.html already exists, skipping.
# michelin_pages/page_26/restaurant_512.html already exists, skipping.
# michelin_pages/page_26/restaurant_513.html already exists, skipping.
# michelin_pages/page_26/restaurant_514.html already exists, skipping.
# michelin_pages/page_26/restaurant_515.html already exists, skipping.
# michelin_pages/page_26/restaurant_516.html already exists, skipping.
# michelin_pages/page_26/restaurant_517.html already exists, skipping.
# michelin_pages/page_26/restaurant_518.html already exists, skipping.
# michelin_pages/page_26/restaurant_519.html already exists, skipping.
# michelin_pages/page_26/restaurant_520.html already exists, skipping.
# michelin_pages/page_27/restaurant_521.html already exists, skipping.
# michelin_pages/page_27/restaurant_522.html already exists, skipping.
# michelin_pages/page_27/restaurant_523.html already exists, skipping.
# michelin_pages/page_27/restaurant_524.html already exists, skipping.
# michelin_pages/page_27/restaurant_525.html already exists, skipping.
# michelin_pages/page_27/restaurant_526.html already exists, skipping.
# michelin_pages/page_27/restaurant_527.html already exists, skipping.
# michelin_pages/page_27/restaurant_528.html already exists, skipping.
# michelin_pages/page_27/restaurant_529.html already exists, skipping.
# michelin_pages/page_27/restaurant_530.html already exists, skipping.
# michelin_pages/page_27/restaurant_531.html already exists, skipping.
# michelin_pages/page_27/restaurant_532.html already exists, skipping.
# michelin_pages/page_27/restaurant_533.html already exists, skipping.
# michelin_pages/page_27/restaurant_534.html already exists, skipping.
# michelin_pages/page_27/restaurant_535.html already exists, skipping.
# michelin_pages/page_27/restaurant_536.html already exists, skipping.
# michelin_pages/page_27/restaurant_537.html already exists, skipping.
# michelin_pages/page_27/restaurant_538.html already exists, skipping.
# michelin_pages/page_27/restaurant_539.html already exists, skipping.
# michelin_pages/page_27/restaurant_540.html already exists, skipping.
# michelin_pages/page_28/restaurant_541.html already exists, skipping.
# michelin_pages/page_28/restaurant_542.html already exists, skipping.
# michelin_pages/page_28/restaurant_543.html already exists, skipping.
# michelin_pages/page_28/restaurant_544.html already exists, skipping.
# michelin_pages/page_28/restaurant_545.html already exists, skipping.
# michelin_pages/page_28/restaurant_546.html already exists, skipping.
# michelin_pages/page_28/restaurant_547.html already exists, skipping.
# michelin_pages/page_28/restaurant_548.html already exists, skipping.
# michelin_pages/page_28/restaurant_549.html already exists, skipping.
# michelin_pages/page_28/restaurant_550.html already exists, skipping.
# michelin_pages/page_28/restaurant_551.html already exists, skipping.
# michelin_pages/page_28/restaurant_552.html already exists, skipping.
# michelin_pages/page_28/restaurant_553.html already exists, skipping.
# michelin_pages/page_28/restaurant_554.html already exists, skipping.
# michelin_pages/page_28/restaurant_555.html already exists, skipping.
# michelin_pages/page_28/restaurant_556.html already exists, skipping.
# michelin_pages/page_28/restaurant_557.html already exists, skipping.
# michelin_pages/page_28/restaurant_558.html already exists, skipping.
# michelin_pages/page_28/restaurant_559.html already exists, skipping.
# michelin_pages/page_28/restaurant_560.html already exists, skipping.
# michelin_pages/page_29/restaurant_561.html already exists, skipping.
# michelin_pages/page_29/restaurant_562.html already exists, skipping.
# michelin_pages/page_29/restaurant_563.html already exists, skipping.
# michelin_pages/page_29/restaurant_564.html already exists, skipping.
# michelin_pages/page_29/restaurant_565.html already exists, skipping.
# michelin_pages/page_29/restaurant_566.html already exists, skipping.
# michelin_pages/page_29/restaurant_567.html already exists, skipping.
# michelin_pages/page_29/restaurant_568.html already exists, skipping.
# michelin_pages/page_29/restaurant_569.html already exists, skipping.
# michelin_pages/page_29/restaurant_570.html already exists, skipping.
# michelin_pages/page_29/restaurant_571.html already exists, skipping.
# michelin_pages/page_29/restaurant_572.html already exists, skipping.
# michelin_pages/page_29/restaurant_573.html already exists, skipping.
# michelin_pages/page_29/restaurant_574.html already exists, skipping.
# michelin_pages/page_29/restaurant_575.html already exists, skipping.
# michelin_pages/page_29/restaurant_576.html already exists, skipping.
# michelin_pages/page_29/restaurant_577.html already exists, skipping.
# michelin_pages/page_29/restaurant_578.html already exists, skipping.
# michelin_pages/page_29/restaurant_579.html already exists, skipping.
# michelin_pages/page_29/restaurant_580.html already exists, skipping.
# michelin_pages/page_30/restaurant_581.html already exists, skipping.
# michelin_pages/page_30/restaurant_582.html already exists, skipping.
# michelin_pages/page_30/restaurant_583.html already exists, skipping.
# michelin_pages/page_30/restaurant_584.html already exists, skipping.
# michelin_pages/page_30/restaurant_585.html already exists, skipping.
# michelin_pages/page_30/restaurant_586.html already exists, skipping.
# michelin_pages/page_30/restaurant_587.html already exists, skipping.
# michelin_pages/page_30/restaurant_588.html already exists, skipping.
# michelin_pages/page_30/restaurant_589.html already exists, skipping.
# michelin_pages/page_30/restaurant_590.html already exists, skipping.
# michelin_pages/page_30/restaurant_591.html already exists, skipping.
# michelin_pages/page_30/restaurant_592.html already exists, skipping.
# michelin_pages/page_30/restaurant_593.html already exists, skipping.
# michelin_pages/page_30/restaurant_594.html already exists, skipping.
# michelin_pages/page_30/restaurant_595.html already exists, skipping.
# michelin_pages/page_30/restaurant_596.html already exists, skipping.
# michelin_pages/page_30/restaurant_597.html already exists, skipping.
# michelin_pages/page_30/restaurant_598.html already exists, skipping.
# michelin_pages/page_30/restaurant_599.html already exists, skipping.
# michelin_pages/page_30/restaurant_600.html already exists, skipping.
# michelin_pages/page_31/restaurant_601.html already exists, skipping.
# michelin_pages/page_31/restaurant_602.html already exists, skipping.
# michelin_pages/page_31/restaurant_603.html already exists, skipping.
# michelin_pages/page_31/restaurant_604.html already exists, skipping.
# michelin_pages/page_31/restaurant_605.html already exists, skipping.
# michelin_pages/page_31/restaurant_606.html already exists, skipping.
# michelin_pages/page_31/restaurant_607.html already exists, skipping.
# michelin_pages/page_31/restaurant_608.html already exists, skipping.
# michelin_pages/page_31/restaurant_609.html already exists, skipping.
# michelin_pages/page_31/restaurant_610.html already exists, skipping.
# michelin_pages/page_31/restaurant_611.html already exists, skipping.
# michelin_pages/page_31/restaurant_612.html already exists, skipping.
# michelin_pages/page_31/restaurant_613.html already exists, skipping.
# michelin_pages/page_31/restaurant_614.html already exists, skipping.
# michelin_pages/page_31/restaurant_615.html already exists, skipping.
# michelin_pages/page_31/restaurant_616.html already exists, skipping.
# michelin_pages/page_31/restaurant_617.html already exists, skipping.
# michelin_pages/page_31/restaurant_618.html already exists, skipping.
# michelin_pages/page_31/restaurant_619.html already exists, skipping.
# michelin_pages/page_31/restaurant_620.html already exists, skipping.
# michelin_pages/page_32/restaurant_621.html already exists, skipping.
# michelin_pages/page_32/restaurant_622.html already exists, skipping.
# michelin_pages/page_32/restaurant_623.html already exists, skipping.
# michelin_pages/page_32/restaurant_624.html already exists, skipping.
# michelin_pages/page_32/restaurant_625.html already exists, skipping.
# michelin_pages/page_32/restaurant_626.html already exists, skipping.
# michelin_pages/page_32/restaurant_627.html already exists, skipping.
# michelin_pages/page_32/restaurant_628.html already exists, skipping.
# michelin_pages/page_32/restaurant_629.html already exists, skipping.
# michelin_pages/page_32/restaurant_630.html already exists, skipping.
# michelin_pages/page_32/restaurant_631.html already exists, skipping.
# michelin_pages/page_32/restaurant_632.html already exists, skipping.
# michelin_pages/page_32/restaurant_633.html already exists, skipping.
# michelin_pages/page_32/restaurant_634.html already exists, skipping.
# michelin_pages/page_32/restaurant_635.html already exists, skipping.
# michelin_pages/page_32/restaurant_636.html already exists, skipping.
# michelin_pages/page_32/restaurant_637.html already exists, skipping.
# michelin_pages/page_32/restaurant_638.html already exists, skipping.
# michelin_pages/page_32/restaurant_639.html already exists, skipping.
# michelin_pages/page_32/restaurant_640.html already exists, skipping.
# michelin_pages/page_33/restaurant_641.html already exists, skipping.
# michelin_pages/page_33/restaurant_642.html already exists, skipping.
# michelin_pages/page_33/restaurant_643.html already exists, skipping.
# michelin_pages/page_33/restaurant_644.html already exists, skipping.
# michelin_pages/page_33/restaurant_645.html already exists, skipping.
# michelin_pages/page_33/restaurant_646.html already exists, skipping.
# michelin_pages/page_33/restaurant_647.html already exists, skipping.
# michelin_pages/page_33/restaurant_648.html already exists, skipping.
# michelin_pages/page_33/restaurant_649.html already exists, skipping.
# michelin_pages/page_33/restaurant_650.html already exists, skipping.
# michelin_pages/page_33/restaurant_651.html already exists, skipping.
# michelin_pages/page_33/restaurant_652.html already exists, skipping.
# michelin_pages/page_33/restaurant_653.html already exists, skipping.
# michelin_pages/page_33/restaurant_654.html already exists, skipping.
# michelin_pages/page_33/restaurant_655.html already exists, skipping.
# michelin_pages/page_33/restaurant_656.html already exists, skipping.
# michelin_pages/page_33/restaurant_657.html already exists, skipping.
# michelin_pages/page_33/restaurant_658.html already exists, skipping.
# michelin_pages/page_33/restaurant_659.html already exists, skipping.
# michelin_pages/page_33/restaurant_660.html already exists, skipping.
# michelin_pages/page_34/restaurant_661.html already exists, skipping.
# michelin_pages/page_34/restaurant_662.html already exists, skipping.
# michelin_pages/page_34/restaurant_663.html already exists, skipping.
# michelin_pages/page_34/restaurant_664.html already exists, skipping.
# michelin_pages/page_34/restaurant_665.html already exists, skipping.
# michelin_pages/page_34/restaurant_666.html already exists, skipping.
# michelin_pages/page_34/restaurant_667.html already exists, skipping.
# michelin_pages/page_34/restaurant_668.html already exists, skipping.
# michelin_pages/page_34/restaurant_669.html already exists, skipping.
# michelin_pages/page_34/restaurant_670.html already exists, skipping.
# michelin_pages/page_34/restaurant_671.html already exists, skipping.
# michelin_pages/page_34/restaurant_672.html already exists, skipping.
# michelin_pages/page_34/restaurant_673.html already exists, skipping.
# michelin_pages/page_34/restaurant_674.html already exists, skipping.
# michelin_pages/page_34/restaurant_675.html already exists, skipping.
# michelin_pages/page_34/restaurant_676.html already exists, skipping.
# michelin_pages/page_34/restaurant_677.html already exists, skipping.
# michelin_pages/page_34/restaurant_678.html already exists, skipping.
# michelin_pages/page_34/restaurant_679.html already exists, skipping.
# michelin_pages/page_34/restaurant_680.html already exists, skipping.
# michelin_pages/page_35/restaurant_681.html already exists, skipping.
# michelin_pages/page_35/restaurant_682.html already exists, skipping.
# michelin_pages/page_35/restaurant_683.html already exists, skipping.
# michelin_pages/page_35/restaurant_684.html already exists, skipping.
# michelin_pages/page_35/restaurant_685.html already exists, skipping.
# michelin_pages/page_35/restaurant_686.html already exists, skipping.
# michelin_pages/page_35/restaurant_687.html already exists, skipping.
# michelin_pages/page_35/restaurant_688.html already exists, skipping.
# michelin_pages/page_35/restaurant_689.html already exists, skipping.
# michelin_pages/page_35/restaurant_690.html already exists, skipping.
# michelin_pages/page_35/restaurant_691.html already exists, skipping.
# michelin_pages/page_35/restaurant_692.html already exists, skipping.
# michelin_pages/page_35/restaurant_693.html already exists, skipping.
# michelin_pages/page_35/restaurant_694.html already exists, skipping.
# michelin_pages/page_35/restaurant_695.html already exists, skipping.
# michelin_pages/page_35/restaurant_696.html already exists, skipping.
# michelin_pages/page_35/restaurant_697.html already exists, skipping.
# michelin_pages/page_35/restaurant_698.html already exists, skipping.
# michelin_pages/page_35/restaurant_699.html already exists, skipping.
# ...
# michelin_pages/page_88/restaurant_1754.html already exists, skipping.
# michelin_pages/page_88/restaurant_1755.html already exists, skipping.
# michelin_pages/page_88/restaurant_1756.html already exists, skipping.
# michelin_pages/page_88/restaurant_1757.html already exists, skipping.
# michelin_pages/page_88/restaurant_1758.html already exists, skipping.
# michelin_pages/page_88/restaurant_1759.html already exists, skipping.
# michelin_pages/page_88/restaurant_1760.html already exists, skipping.
# michelin_pages/page_89/restaurant_1761.html already exists, skipping.
# michelin_pages/page_89/restaurant_1762.html already exists, skipping.
# michelin_pages/page_89/restaurant_1763.html already exists, skipping.
# michelin_pages/page_89/restaurant_1764.html already exists, skipping.
# michelin_pages/page_89/restaurant_1765.html already exists, skipping.
# michelin_pages/page_89/restaurant_1766.html already exists, skipping.
# michelin_pages/page_89/restaurant_1767.html already exists, skipping.
# michelin_pages/page_89/restaurant_1768.html already exists, skipping.
# michelin_pages/page_89/restaurant_1769.html already exists, skipping.
# michelin_pages/page_89/restaurant_1770.html already exists, skipping.
# michelin_pages/page_89/restaurant_1771.html already exists, skipping.
# michelin_pages/page_89/restaurant_1772.html already exists, skipping.
# michelin_pages/page_89/restaurant_1773.html already exists, skipping.
# michelin_pages/page_89/restaurant_1774.html already exists, skipping.
# michelin_pages/page_89/restaurant_1775.html already exists, skipping.
# michelin_pages/page_89/restaurant_1776.html already exists, skipping.
# michelin_pages/page_89/restaurant_1777.html already exists, skipping.
# michelin_pages/page_89/restaurant_1778.html already exists, skipping.
# michelin_pages/page_89/restaurant_1779.html already exists, skipping.
# michelin_pages/page_89/restaurant_1780.html already exists, skipping.
# michelin_pages/page_90/restaurant_1781.html already exists, skipping.
# michelin_pages/page_90/restaurant_1782.html already exists, skipping.
# michelin_pages/page_90/restaurant_1783.html already exists, skipping.
# michelin_pages/page_90/restaurant_1784.html already exists, skipping.
# michelin_pages/page_90/restaurant_1785.html already exists, skipping.
# michelin_pages/page_90/restaurant_1786.html already exists, skipping.
# michelin_pages/page_90/restaurant_1787.html already exists, skipping.
# michelin_pages/page_90/restaurant_1788.html already exists, skipping.
# michelin_pages/page_90/restaurant_1789.html already exists, skipping.
# michelin_pages/page_90/restaurant_1790.html already exists, skipping.
# michelin_pages/page_90/restaurant_1791.html already exists, skipping.
# michelin_pages/page_90/restaurant_1792.html already exists, skipping.
# michelin_pages/page_90/restaurant_1793.html already exists, skipping.
# michelin_pages/page_90/restaurant_1794.html already exists, skipping.
# michelin_pages/page_90/restaurant_1795.html already exists, skipping.
# michelin_pages/page_90/restaurant_1796.html already exists, skipping.
# michelin_pages/page_90/restaurant_1797.html already exists, skipping.
# michelin_pages/page_90/restaurant_1798.html already exists, skipping.
# michelin_pages/page_90/restaurant_1799.html already exists, skipping.
# michelin_pages/page_90/restaurant_1800.html already exists, skipping.
# michelin_pages/page_91/restaurant_1801.html already exists, skipping.
# michelin_pages/page_91/restaurant_1802.html already exists, skipping.
# michelin_pages/page_91/restaurant_1803.html already exists, skipping.
# michelin_pages/page_91/restaurant_1804.html already exists, skipping.
# michelin_pages/page_91/restaurant_1805.html already exists, skipping.
# michelin_pages/page_91/restaurant_1806.html already exists, skipping.
# michelin_pages/page_91/restaurant_1807.html already exists, skipping.
# michelin_pages/page_91/restaurant_1808.html already exists, skipping.
# michelin_pages/page_91/restaurant_1809.html already exists, skipping.
# michelin_pages/page_91/restaurant_1810.html already exists, skipping.
# michelin_pages/page_91/restaurant_1811.html already exists, skipping.
# michelin_pages/page_91/restaurant_1812.html already exists, skipping.
# michelin_pages/page_91/restaurant_1813.html already exists, skipping.
# michelin_pages/page_91/restaurant_1814.html already exists, skipping.
# michelin_pages/page_91/restaurant_1815.html already exists, skipping.
# michelin_pages/page_91/restaurant_1816.html already exists, skipping.
# michelin_pages/page_91/restaurant_1817.html already exists, skipping.
# michelin_pages/page_91/restaurant_1818.html already exists, skipping.
# michelin_pages/page_91/restaurant_1819.html already exists, skipping.
# michelin_pages/page_91/restaurant_1820.html already exists, skipping.
# michelin_pages/page_92/restaurant_1821.html already exists, skipping.
# michelin_pages/page_92/restaurant_1822.html already exists, skipping.
# michelin_pages/page_92/restaurant_1823.html already exists, skipping.
# michelin_pages/page_92/restaurant_1824.html already exists, skipping.
# michelin_pages/page_92/restaurant_1825.html already exists, skipping.
# michelin_pages/page_92/restaurant_1826.html already exists, skipping.
# michelin_pages/page_92/restaurant_1827.html already exists, skipping.
# michelin_pages/page_92/restaurant_1828.html already exists, skipping.
# michelin_pages/page_92/restaurant_1829.html already exists, skipping.
# michelin_pages/page_92/restaurant_1830.html already exists, skipping.
# michelin_pages/page_92/restaurant_1831.html already exists, skipping.
# michelin_pages/page_92/restaurant_1832.html already exists, skipping.
# michelin_pages/page_92/restaurant_1833.html already exists, skipping.
# michelin_pages/page_92/restaurant_1834.html already exists, skipping.
# michelin_pages/page_92/restaurant_1835.html already exists, skipping.
# michelin_pages/page_92/restaurant_1836.html already exists, skipping.
# michelin_pages/page_92/restaurant_1837.html already exists, skipping.
# michelin_pages/page_92/restaurant_1838.html already exists, skipping.
# michelin_pages/page_92/restaurant_1839.html already exists, skipping.
# michelin_pages/page_92/restaurant_1840.html already exists, skipping.
# michelin_pages/page_93/restaurant_1841.html already exists, skipping.
# michelin_pages/page_93/restaurant_1842.html already exists, skipping.
# michelin_pages/page_93/restaurant_1843.html already exists, skipping.
# michelin_pages/page_93/restaurant_1844.html already exists, skipping.
# michelin_pages/page_93/restaurant_1845.html already exists, skipping.
# michelin_pages/page_93/restaurant_1846.html already exists, skipping.
# michelin_pages/page_93/restaurant_1847.html already exists, skipping.
# michelin_pages/page_93/restaurant_1848.html already exists, skipping.
# michelin_pages/page_93/restaurant_1849.html already exists, skipping.
# michelin_pages/page_93/restaurant_1850.html already exists, skipping.
# michelin_pages/page_93/restaurant_1851.html already exists, skipping.
# michelin_pages/page_93/restaurant_1852.html already exists, skipping.
# michelin_pages/page_93/restaurant_1853.html already exists, skipping.
# michelin_pages/page_93/restaurant_1854.html already exists, skipping.
# michelin_pages/page_93/restaurant_1855.html already exists, skipping.
# michelin_pages/page_93/restaurant_1856.html already exists, skipping.
# michelin_pages/page_93/restaurant_1857.html already exists, skipping.
# michelin_pages/page_93/restaurant_1858.html already exists, skipping.
# michelin_pages/page_93/restaurant_1859.html already exists, skipping.
# michelin_pages/page_93/restaurant_1860.html already exists, skipping.
# michelin_pages/page_94/restaurant_1861.html already exists, skipping.
# michelin_pages/page_94/restaurant_1862.html already exists, skipping.
# michelin_pages/page_94/restaurant_1863.html already exists, skipping.
# michelin_pages/page_94/restaurant_1864.html already exists, skipping.
# michelin_pages/page_94/restaurant_1865.html already exists, skipping.
# michelin_pages/page_94/restaurant_1866.html already exists, skipping.
# michelin_pages/page_94/restaurant_1867.html already exists, skipping.
# michelin_pages/page_94/restaurant_1868.html already exists, skipping.
# michelin_pages/page_94/restaurant_1869.html already exists, skipping.
# michelin_pages/page_94/restaurant_1870.html already exists, skipping.
# michelin_pages/page_94/restaurant_1871.html already exists, skipping.
# michelin_pages/page_94/restaurant_1872.html already exists, skipping.
# michelin_pages/page_94/restaurant_1873.html already exists, skipping.
# michelin_pages/page_94/restaurant_1874.html already exists, skipping.
# michelin_pages/page_94/restaurant_1875.html already exists, skipping.
# michelin_pages/page_94/restaurant_1876.html already exists, skipping.
# michelin_pages/page_94/restaurant_1877.html already exists, skipping.
# michelin_pages/page_94/restaurant_1878.html already exists, skipping.
# michelin_pages/page_94/restaurant_1879.html already exists, skipping.
# michelin_pages/page_94/restaurant_1880.html already exists, skipping.
# michelin_pages/page_95/restaurant_1881.html already exists, skipping.
# michelin_pages/page_95/restaurant_1882.html already exists, skipping.
# michelin_pages/page_95/restaurant_1883.html already exists, skipping.
# michelin_pages/page_95/restaurant_1884.html already exists, skipping.
# michelin_pages/page_95/restaurant_1885.html already exists, skipping.
# michelin_pages/page_95/restaurant_1886.html already exists, skipping.
# michelin_pages/page_95/restaurant_1887.html already exists, skipping.
# michelin_pages/page_95/restaurant_1888.html already exists, skipping.
# michelin_pages/page_95/restaurant_1889.html already exists, skipping.
# michelin_pages/page_95/restaurant_1890.html already exists, skipping.
# michelin_pages/page_95/restaurant_1891.html already exists, skipping.
# michelin_pages/page_95/restaurant_1892.html already exists, skipping.
# michelin_pages/page_95/restaurant_1893.html already exists, skipping.
# michelin_pages/page_95/restaurant_1894.html already exists, skipping.
# michelin_pages/page_95/restaurant_1895.html already exists, skipping.
# michelin_pages/page_95/restaurant_1896.html already exists, skipping.
# michelin_pages/page_95/restaurant_1897.html already exists, skipping.
# michelin_pages/page_95/restaurant_1898.html already exists, skipping.
# michelin_pages/page_95/restaurant_1899.html already exists, skipping.
# michelin_pages/page_95/restaurant_1900.html already exists, skipping.
# michelin_pages/page_96/restaurant_1901.html already exists, skipping.
# michelin_pages/page_96/restaurant_1902.html already exists, skipping.
# michelin_pages/page_96/restaurant_1903.html already exists, skipping.
# michelin_pages/page_96/restaurant_1904.html already exists, skipping.
# michelin_pages/page_96/restaurant_1905.html already exists, skipping.
# michelin_pages/page_96/restaurant_1906.html already exists, skipping.
# michelin_pages/page_96/restaurant_1907.html already exists, skipping.
# michelin_pages/page_96/restaurant_1908.html already exists, skipping.
# michelin_pages/page_96/restaurant_1909.html already exists, skipping.
# michelin_pages/page_96/restaurant_1910.html already exists, skipping.
# michelin_pages/page_96/restaurant_1911.html already exists, skipping.
# michelin_pages/page_96/restaurant_1912.html already exists, skipping.
# michelin_pages/page_96/restaurant_1913.html already exists, skipping.
# michelin_pages/page_96/restaurant_1914.html already exists, skipping.
# michelin_pages/page_96/restaurant_1915.html already exists, skipping.
# michelin_pages/page_96/restaurant_1916.html already exists, skipping.
# michelin_pages/page_96/restaurant_1917.html already exists, skipping.
# michelin_pages/page_96/restaurant_1918.html already exists, skipping.
# michelin_pages/page_96/restaurant_1919.html already exists, skipping.
# michelin_pages/page_96/restaurant_1920.html already exists, skipping.
# michelin_pages/page_97/restaurant_1921.html already exists, skipping.
# michelin_pages/page_97/restaurant_1922.html already exists, skipping.
# michelin_pages/page_97/restaurant_1923.html already exists, skipping.
# michelin_pages/page_97/restaurant_1924.html already exists, skipping.
# michelin_pages/page_97/restaurant_1925.html already exists, skipping.
# michelin_pages/page_97/restaurant_1926.html already exists, skipping.
# michelin_pages/page_97/restaurant_1927.html already exists, skipping.
# michelin_pages/page_97/restaurant_1928.html already exists, skipping.
# michelin_pages/page_97/restaurant_1929.html already exists, skipping.
# michelin_pages/page_97/restaurant_1930.html already exists, skipping.
# michelin_pages/page_97/restaurant_1931.html already exists, skipping.
# michelin_pages/page_97/restaurant_1932.html already exists, skipping.
# michelin_pages/page_97/restaurant_1933.html already exists, skipping.
# michelin_pages/page_97/restaurant_1934.html already exists, skipping.
# michelin_pages/page_97/restaurant_1935.html already exists, skipping.
# michelin_pages/page_97/restaurant_1936.html already exists, skipping.
# michelin_pages/page_97/restaurant_1937.html already exists, skipping.
# michelin_pages/page_97/restaurant_1938.html already exists, skipping.
# michelin_pages/page_97/restaurant_1939.html already exists, skipping.
# michelin_pages/page_97/restaurant_1940.html already exists, skipping.
# michelin_pages/page_98/restaurant_1941.html already exists, skipping.
# michelin_pages/page_98/restaurant_1942.html already exists, skipping.
# michelin_pages/page_98/restaurant_1943.html already exists, skipping.
# michelin_pages/page_98/restaurant_1944.html already exists, skipping.
# michelin_pages/page_98/restaurant_1945.html already exists, skipping.
# michelin_pages/page_98/restaurant_1946.html already exists, skipping.
# michelin_pages/page_98/restaurant_1947.html already exists, skipping.
# michelin_pages/page_98/restaurant_1948.html already exists, skipping.
# michelin_pages/page_98/restaurant_1949.html already exists, skipping.
# michelin_pages/page_98/restaurant_1950.html already exists, skipping.
# michelin_pages/page_98/restaurant_1951.html already exists, skipping.
# michelin_pages/page_98/restaurant_1952.html already exists, skipping.
# michelin_pages/page_98/restaurant_1953.html already exists, skipping.
# michelin_pages/page_98/restaurant_1954.html already exists, skipping.
# michelin_pages/page_98/restaurant_1955.html already exists, skipping.
# michelin_pages/page_98/restaurant_1956.html already exists, skipping.
# michelin_pages/page_98/restaurant_1957.html already exists, skipping.
# michelin_pages/page_98/restaurant_1958.html already exists, skipping.
# michelin_pages/page_98/restaurant_1959.html already exists, skipping.
# michelin_pages/page_98/restaurant_1960.html already exists, skipping.
# michelin_pages/page_99/restaurant_1961.html already exists, skipping.
# michelin_pages/page_99/restaurant_1962.html already exists, skipping.
# michelin_pages/page_99/restaurant_1963.html already exists, skipping.
# michelin_pages/page_99/restaurant_1964.html already exists, skipping.
# michelin_pages/page_99/restaurant_1965.html already exists, skipping.
# michelin_pages/page_99/restaurant_1966.html already exists, skipping.
# michelin_pages/page_99/restaurant_1967.html already exists, skipping.
# michelin_pages/page_99/restaurant_1968.html already exists, skipping.
# michelin_pages/page_99/restaurant_1969.html already exists, skipping.
# michelin_pages/page_99/restaurant_1970.html already exists, skipping.
# michelin_pages/page_99/restaurant_1971.html already exists, skipping.
# michelin_pages/page_99/restaurant_1972.html already exists, skipping.
# michelin_pages/page_99/restaurant_1973.html already exists, skipping.
# michelin_pages/page_99/restaurant_1974.html already exists, skipping.
# michelin_pages/page_99/restaurant_1975.html already exists, skipping.
# michelin_pages/page_99/restaurant_1976.html already exists, skipping.
# michelin_pages/page_99/restaurant_1977.html already exists, skipping.
# michelin_pages/page_99/restaurant_1978.html already exists, skipping.
# michelin_pages/page_99/restaurant_1979.html already exists, skipping.
# michelin_pages/page_99/restaurant_1980.html already exists, skipping.
# michelin_pages/page_100/restaurant_1981.html already exists, skipping.

# %% [markdown]
# ### -- 1.3 Parse downloaded pages
# At this point, you should have all the HTML documents about the restaurant of interest, and you can start to extract specific information. The list of the information we desire for each restaurant and their format is as follows:
#
# Restaurant Name (to save as restaurantName): string;
# Address (to save as address): string;
# City (to save as city): string;
# Postal Code (to save as postalCode): string;
# Country (to save as country): string;
# Price Range (to save as priceRange): string;
# Cuisine Type (to save as cuisineType): string;
# Description (to save as description): string;
# Facilities and Services (to save as facilitiesServices): list of strings;
# Accepted Credit Cards (to save as creditCards): list of strings;
# Phone Number (to save as phoneNumber): string;
# URL to the Restaurant Page (to save as website): string.

# %%
def parse_restaurant_data(html_file_path):
    # Open and parse the HTML file
    with open(html_file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
    
    # Find the <script> tag containing JSON data
    json_script = soup.find('script', type='application/ld+json')
    if not json_script:
        print(f"JSON data not found: {html_file_path}")
        return None
    
    # Parse JSON data
    restaurant_data = json.loads(json_script.string)
    
    # Extract required fields from JSON data
    data = {
        "restaurantName": restaurant_data.get("name", ""),
        "address": restaurant_data.get("address", {}).get("streetAddress", ""),
        "city": restaurant_data.get("address", {}).get("addressLocality", ""),
        "postalCode": restaurant_data.get("address", {}).get("postalCode", ""),
        "country": restaurant_data.get("address", {}).get("addressCountry", ""),
        # Extract 'priceRange' directly from JSON, if available
        "priceRange": restaurant_data.get("priceRange", ""),
        "cuisineType": restaurant_data.get("servesCuisine", ""),
        "description": restaurant_data.get("review", {}).get("description", ""),
        "facilitiesServices": ["Drive-through" if restaurant_data.get("hasDriveThroughService", False) == "True" else ""],
        "creditCards": restaurant_data.get("paymentAccepted", "").split(", "),
        "phoneNumber": restaurant_data.get("telephone", ""),
        "website": restaurant_data.get("url", "")
    }
    
    # If 'priceRange' is missing in JSON, search for it in the HTML using alternative class names
    if not data["priceRange"]:
        # Try alternative class names like "price-symbol", "price-range", "pricing-info", or "price"
        price_selectors = ["span.price-symbol", "span.price-range", "div.pricing-info", "div.price"]
        for selector in price_selectors:
            price_element = soup.select_one(selector)
            if price_element:
                data["priceRange"] = price_element.get_text(strip=True)
                break  # Stop the loop once a value is found
    
    # If 'priceRange' is still empty, search for any text containing the '€' symbol
    if not data["priceRange"]:
        possible_price_text = soup.find(string=lambda text: "€" in text if text else False)
        if possible_price_text:
            data["priceRange"] = possible_price_text.strip()

    # If 'priceRange' is still not found, display a message
    if not data["priceRange"]:
        print(f"'priceRange' data not found: {html_file_path}")
    
    return data
def save_to_tsv(data, output_folder, file_name):
    os.makedirs(output_folder, exist_ok=True)
    output_path = os.path.join(output_folder, file_name)
    
    # Write each piece of data in 'key=value' format to the TSV file
    with open(output_path, 'w', encoding='utf-8') as file:
        tsv_data = [
            f"restaurantName={data['restaurantName']}",
            f"address={data['address']}",
            f"city={data['city']}",
            f"postalCode={data['postalCode']}",
            f"country={data['country']}",
            f"priceRange={data['priceRange']}",
            f"cuisineType={data['cuisineType']}",
            f"description={data['description']}",
            f"facilitiesServices={'|'.join(data['facilitiesServices'])}",
            f"creditCards={'|'.join(data['creditCards'])}",
            f"phoneNumber={data['phoneNumber']}",
            f"website={data['website']}"
        ]
        file.write('\t'.join(tsv_data) + '\n')

# Define the main folder (e.g., 'michelin_pages')
main_folder = 'michelin_pages'
output_folder = 'tsv'  # Folder to save output TSV files
counter = 1

# Traverse all subfolders and HTML files
for root, dirs, files in os.walk(main_folder):
    for file_name in files:
        if file_name.endswith('.html'):
            file_path = os.path.join(root, file_name)
            data = parse_restaurant_data(file_path)
            if data:
                save_to_tsv(data, output_folder, f'restaurant_{counter}.tsv')
                counter += 1

print(f"All files processed. A total of {counter - 1} TSV files created.")
# Out:
# All files processed. A total of 1981 TSV files created.

# %%
import pandas as pd

# Path to the folder containing TSV files
tsv_folder = 'tsv'  # Assuming the files are saved in the 'tsv' folder
all_data = []  # Create an empty list to store all data
processed_files = 0  # Initialize a counter for processed files

# Read each TSV file and append its data to the list
for file_name in os.listdir(tsv_folder):
    if file_name.endswith('.tsv'):
        file_path = os.path.join(tsv_folder, file_name)
        
        try:
            # Read each TSV file line by line and parse key-value pairs
            with open(file_path, 'r', encoding='utf-8') as file:
                lines = file.readlines()
                data_dict = {}
                for line in lines:
                    # Split each line into 'key=value' pairs and add to data_dict
                    parts = line.strip().split('\t')
                    for part in parts:
                        if '=' in part:  # Ensure there is an '=' character
                            key, value = part.split('=', 1)
                            data_dict[key] = value
                
                # Append the dictionary as a single row to a DataFrame
                all_data.append(pd.DataFrame([data_dict]))
                processed_files += 1  # Increment the processed files counter

        except Exception as e:
            print(f"An error occurred: {e} - File: {file_name}")

# Concatenate all DataFrames
try:
    combined_df = pd.concat(all_data, ignore_index=True)
    print(f"All data combined successfully. Processed files: {processed_files}, Total rows: {len(combined_df)}")
except Exception as e:
    print(f"An error occurred during concatenation: {e}")

# Display the entire table (warning: may be too large if there are many rows)
combined_df
# Out:
# All data combined successfully. Processed files: 1983, Total rows: 1983
#                    restaurantName                         address  \
# 0                 Osteria la Fefa          via Trento-Trieste 9/c
# 1                        Campamac            strada della Valle 1
# 2                         Lucenti                  via Mazzini 38
# 3           La Capanna di Eraclio      Località per Le Venezie 21
# 4           Il Giardino del Gusto         piazza XX Settembre 6/c
# ...                           ...                             ...
# 1978  Il Ristorante - Niko Romito  via Privata Fratelli Gabba 7/b
# 1979          Repubblica di Perno     vicolo Cavour 5, loc. Perno
# 1980                     Dry Aged           via Cesare Da Sesto 1
# 1981              Harry's Piccolo         piazza Unità d'Italia 2
# 1982                       Kohaku                   via Marche 66
#
#                  city postalCode country priceRange            cuisineType  \
# 0       Finale Emilia      41034     ITA         €€                Emilian
# 1          Barbaresco      12050     ITA        €€€            Piedmontese
# 2        Montefiorino      41045     ITA          €                Emilian
# 3            Codigoro      44021     ITA        €€€                Seafood
# 4         Ventimiglia      18039     ITA        €€€               Creative
# ...               ...        ...     ...        ...                    ...
# 1978            Milan      20121     ITA       €€€€   Italian Contemporary
# 1979  Monforte d'Alba      12065     ITA         €€            Piedmontese
# 1980            Milan      20123     ITA         €€           Contemporary
# 1981          Trieste      34121     ITA       €€€€   Italian Contemporary
# 1982             Rome      00187     ITA         €€  Japanese Contemporary
#
#                                             description facilitiesServices  \
# 0     The name “Fefa” is a diminutive of Genoveffa, ...
# 1     A real gourmet inn which serves traditional Pi...
# 2     This small, family - run restaurant furnished ...
# 3     Whenever we visit Capanna di Eraclio, we have ...
# 4     Although not on the seafront, this restaurant ...
# ...                                                 ...                ...
# 1978  Housed within the Bulgari hotel right in the h...
# 1979  Situated in the heart of the gastronomic Langa...
# 1980  Two partners with significant experience opene...
# 1981  Thanks to its hushed ambience, Harry’s Piccolo...
# 1982  As if by magic, once you step over the thresho...
#
#                                             creditCards       phoneNumber  \
# 0     Credit card / Debit card accepted|Mastercard c...   +39 0535 780202
# 1     American Express credit card|Credit card / Deb...   +39 0173 635051
# 2     American Express credit card|Credit card / Deb...   +39 0536 965122
# 3     American Express credit card|Credit card / Deb...   +39 0533 712154
# 4     American Express credit card|Credit card / Deb...   +39 0184 355244
# ...                                                 ...               ...
# 1978  American Express credit card|Credit card / Deb...   +39 02 805 8051
# 1979  Credit card / Debit card accepted|Mastercard c...    +39 0173 78492
# 1980  American Express credit card|Credit card / Deb...  +39 02 5810 7932
# 1981  American Express credit card|Credit card / Deb...    +39 040 660606
# 1982  American Express credit card|Credit card / Deb...  +39 06 4566 5202
#
#                                                 website
# 0     https://guide.michelin.com/en/emilia-romagna/f...
# 1     https://guide.michelin.com/en/piemonte/barbare...
# 2     https://guide.michelin.com/en/emilia-romagna/m...
# 3     https://guide.michelin.com/en/emilia-romagna/c...
# 4     https://guide.michelin.com/en/liguria/ventimig...
# ...                                                 ...
# 1978  https://guide.michelin.com/en/lombardia/milano...
# 1979  https://guide.michelin.com/en/piemonte/monfort...
# 1980  https://guide.michelin.com/en/lombardia/milano...
# 1981  https://guide.michelin.com/en/friuli-venezia-g...
# 1982  https://guide.michelin.com/en/lazio/roma/resta...
#
# [1983 rows x 12 columns]

# %% [markdown]
# ## 2. Search Engine
#
# This search engine allows you to retrieve restaurants based on a user query. We’ll build two types of search engines:
#
# **Conjunctive Search Engine**: Returns restaurants where all query terms appear in the description.
# **Ranked Search Engine**: Returns the top-k restaurants sorted by similarity to the query, using TF-IDF and Cosine Similarity.

# %% [markdown]
# #### Load Dataset

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import os
import heapq
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv("dataset.csv")
data.head()
# Out:
#                             restaurantName              address  \
# 0                           O Me O Il Mare       Via Roma 45/47
# 1                           Alessandro Feo  via Angelo Lista 24
# 2                                 Lalibera   via Pertinace 24/a
# 3  Antica Macelleria Cecchini - Solociccia   via Chiantigiana 5
# 4                                   Brindo       via Libertà 18
#
#                      city postalCode country priceRange  \
# 0                Gragnano      80054   Italy       €€€€
# 1  Marina di Casal Velino      84040   Italy         €€
# 2                    Alba      12051   Italy         €€
# 3                 Panzano      50022   Italy         €€
# 4                  Cusago      20047   Italy          €
#
#                             cuisineType  \
# 0  Italian Contemporary, Modern Cuisine
# 1                    Campanian, Seafood
# 2      Piedmontese, Traditional Cuisine
# 3                      Meats and Grills
# 4                            Lombardian
#
#                                          description  \
# 0  After many years’ experience in Michelin-starr...
# 1  In a beautiful stone-vaulted building (an old ...
# 2  A modern, designer-style restaurant staffed by...
# 3  One of the most famous butchers in Italy has n...
# 4  The service is characterized by a cohesive and...
#
#                                   facilitiesServices  \
# 0  Air conditioning|Interesting wine list|Wheelch...
# 1                                                NaN
# 2             Air conditioning|Interesting wine list
# 3  Air conditioning|Bring your own bottle|Restaur...
# 4                                   Air conditioning
#
#                        creditCards       phoneNumber  \
# 0  amex|dinersclub|mastercard|visa  +39 081 620 0550
# 1  amex|dinersclub|mastercard|visa  +39 328 893 7083
# 2             amex|mastercard|visa   +39 0173 293155
# 3             amex|mastercard|visa    +39 055 852020
# 4             amex|mastercard|visa  +39 02 9039 4429
#
#                                    website
# 0                    http://omeoilmare.com
# 1  https://www.alessandrofeoristorante.it/
# 2                    https://lalibera.com/
# 3            https://www.dariocecchini.com
# 4                    https://www.brindo.it

# %%
data.isnull().sum()
# Out:
# restaurantName          0
# address                 0
# city                    0
# postalCode              1
# country                 0
# priceRange              0
# cuisineType             0
# description             0
# facilitiesServices     24
# creditCards             3
# phoneNumber             0
# website               108
# dtype: int64

# %%
# Replace null values in all columns with an empty string
data = data.fillna('')
data.isnull().sum()
# Out:
# restaurantName        0
# address               0
# city                  0
# postalCode            0
# country               0
# priceRange            0
# cuisineType           0
# description           0
# facilitiesServices    0
# creditCards           0
# phoneNumber           0
# website               0
# dtype: int64

# %%
data.shape
# Out:
# (1981, 12)

# %% [markdown]
# #### 2.0 Preprocessing

# %% [markdown]
# ##### 2.0.0) Preprocessing text
# Before building the search engine, you must clean and prepare the text in each restaurant’s description. We will:
#
# Remove stopwords.
# Remove punctuation.
# Apply stemming.
# Perform any other necessary cleaning to improve search accuracy.
# For this, we use the nltk library.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import string
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\matteo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\matteo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\matteo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Replace non-standard apostrophes with standard ones
    text = text.replace("’", "'")
    # Remove punctuation
    no_punctuation = [char for char in text if char not in string.punctuation]
    text = ''.join(no_punctuation)

    # Tokenization (split the text into words)
    words = word_tokenize(text)

    # Remove stopwords in English
    stop_words = set(stopwords.words('english'))  # Stopwords for English
    filtered_words = [word for word in words if word not in stop_words]

    # Apply stemming using PorterStemmer
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]

    # Return the processed text as a string
    return ' '.join(stemmed_words)

# %%
# Ensure that all descriptions are strings and apply the preprocess function
data['cleaned_description'] = data['description'].apply(preprocess_text)

# %% [markdown]
# #### 2.1 Conjuctive Query
# This first version of the search engine narrows the search to the description field of each restaurant. Only restaurants whose descriptions contain all the query words will be returned.

# %% [markdown]
# ##### 2.1.1 Create Your Index!
# **Vocabulary File**: Create a file called vocabulary.csv that maps each word to a unique integer (term_id).
#
# **Inverted Index**: Build a dictionary mapping each term_id to a list of document IDs where that term appears.

# %%
import pandas as pd
from collections import defaultdict

# Step 1: Create the Vocabulary File

# 1. Tokenize the cleaned descriptions and create a set of unique words
unique_words = set()
for description in data['cleaned_description']:
    unique_words.update(description.split())

# 2. Create a vocabulary mapping word to term_id
vocabulary = {word: idx + 1 for idx, word in enumerate(sorted(unique_words))}

# Convert vocabulary to DataFrame and save as CSV
vocabulary_df = pd.DataFrame(list(vocabulary.items()), columns=['word', 'term_id'])
vocabulary_df.to_csv('vocabulary.csv', index=False)

# Step 2: Build the Inverted Index

# Initialize inverted index as a defaultdict
inverted_index = defaultdict(list)

# Iterate through each document (restaurant description)
for doc_id, description in enumerate(data['cleaned_description'], start=0):
    words_in_doc = set(description.split())  # Get unique words in the description
    for word in words_in_doc:
        if word in vocabulary:  # Ensure word exists in vocabulary
            term_id = vocabulary[word]
            inverted_index[term_id].append(doc_id)

# Save the inverted index to a file
import json
with open('inverted_index.json', 'w') as f:
    json.dump(inverted_index, f)

# %% [markdown]
# ##### 2.1.2 Execute the Query
#
# When the user inputs a query, for example, "modern seasonal cuisine", the search engine will:
#
# Process the query terms.
# Find and return a list of restaurants containing all query words in their description.

# %%
import json
import pandas as pd

with open('inverted_index.json', 'r') as file:
    inverted_index = json.load(file)

# Function to process the input query and find matching restaurants
def process_query(query):
    # Tokenize and clean the query
    query_terms = word_tokenize(preprocess_text(query))

    # Find term IDs for query words
    term_ids = []
    for term in query_terms:
        # Look for term in the inverted index and get corresponding term_id(s)
        # Here we assume that `inverted_index` maps term IDs to document IDs
        term_id = vocabulary_df[vocabulary_df['word']==term]['term_id'].iloc[0]  # Simple example, you'd map from term to term_id
        if str(term_id) in inverted_index.keys():
            term_ids.append(str(term_id))

    # Find restaurants that contain all query terms
    matching_restaurants = set(inverted_index[term_ids[0]]) if term_ids else set()
    for term_id in term_ids[1:]:
        matching_restaurants &= set(inverted_index[term_id])  # Set intersection

    # Get restaurant details for matching restaurant IDs
    results = []
    for idx in matching_restaurants:
        restaurant = data.iloc[idx]
        results.append({
            'restaurantName': restaurant['restaurantName'],
            'address': restaurant['address'],
            'description': restaurant['description'],
            'website': restaurant['website']
        })

    return results

# %%
# Example usage:
query = "modern seasonal cuisine"
matching_restaurants = process_query(query)

# Output the results
for result in matching_restaurants[:5]:
    print(f"Name: {result['restaurantName']}")
    print(f"Address: {result['address']}")
    print(f"Description: {result['description']}")
    print(f"Website: {result['website']}\n")
# Out:
# Name: Winter Garden Florence
# Address: piazza Ognissanti 1
# Description: Horse-drawn carriages once entered the old courtyard of the St Regis hotel, now converted into an elegant winter garden which also includes a cocktail bar with sofas and armchairs. Seasonality and local gems are fundamental pillars of the modern Mediterranean cuisine.
# Website: https://www.wintergardenflorence.com/it/
#
# Name: Retrobottega
# Address: via della Stelletta 4
# Description: Minimalist decor and clean lines characterise this restaurant decorated in dark tones, where the two owner-chefs have both worked in various Michelin-starred restaurants (and others) over the years. Modern cuisine which showcases seasonal ingredients in regional yet refined dishes.
# Website: https://www.retro-bottega.com
#
# Name: Locanda Solagna
# Address: piazza I  Novembre 2
# Description: Although this restaurant has been in business since the 1950s, it feels much more modern thanks to its updated appearance. Renowned for its excellent regional cuisine served in the evening, the restaurant pays careful attention to seasonal ingredients. At lunchtime, the ”osteria”-style menu is much simpler. Excellent wine selection.
# Website: https://www.locandasolagna.it/
#
# Name: Osteria del Miglio 2.10
# Address: via Patrioti 2
# Description: Although the town may not be of major importance, the cuisine served at this modern restaurant (with a convenient car park) certainly is! Focusing on traditional local recipes and using seasonal ingredients, the carefully prepared dishes are both generous and full of flavour. Fair prices complete the picture and make this a restaurant a must.
# Website:
#
# Name: Savô
# Address: piazza XXV Aprile 8
# Description: The reopening in 2022 of the Hotel Windsor with its romantic vintage decor, is a real bonus for Laigueglia, especially the hotel’s new gourmet restaurant Savô (which translates as “flavour” in Ligurian dialect). Here, a contemporary dining room and an outdoor space with views of the beach and the sea provide the setting for modern cuisine prepared from regional, seasonal ingredients with a focus on fish (there is also a meat option for each course). The impressive selection of wine and choice of cocktails from the elegant Windsor Bar adds to its appeal.
# Website: http://www.thewindsor.it

# %% [markdown]
# #### 2.2 Ranked Search Engine with TF-IDF and Cosine Similarity
# For the second search engine, given a query, retrieve the top-k restaurants ranked by relevance to the query.

# %% [markdown]
# ##### 2.2.1 Inverted Index with TF-IDF Scores
# - **TF-IDF Scores**: Calculate TF-IDF scores for each term in each restaurant’s description.
# - **Updated Inverted Index**: Build a new inverted index where each entry is a term, and the value is a list of tuples containing document IDs and TF-IDF scores.

# %% [markdown]
# Calculate **Term Frequencies (TF)**\
# For each document (restaurant description), we count how frequently each term appears and normalize by the total word count.

# %%
from collections import Counter
import numpy as np

# Initialize a dictionary to store term frequencies for each document
tf_dict = {}

# Calculate term frequency for each document
for doc_id, description in enumerate(data['cleaned_description'], start=0):
    word_counts = Counter(description.split())  # Count word occurrences
    total_words = sum(word_counts.values())  # Total words in the document
    tf_dict[doc_id] = {word: count / total_words for word, count in word_counts.items()}

# %% [markdown]
# Calculate **Document Frequencies (DF)**\
# Document Frequency measures how many documents each term appears in.

# %%
# Initialize a dictionary to count document frequencies
df_dict = Counter()

# Calculate document frequency for each term
for description in data['cleaned_description']:
    words_in_doc = set(description.split())  # Unique words in the document
    df_dict.update(words_in_doc)

# Total number of documents
N = len(data)

#df_dict

# %% [markdown]
# **Calculate TF-IDF Scores** \
# For each document, compute TF-IDF for all terms.

# %%
tfidf_scores = {}

# Calculate TF-IDF for each document
for doc_id, term_frequencies in tf_dict.items():
    tfidf_scores[doc_id] = {}
    for term, tf in term_frequencies.items():
        idf = np.log(N / (df_dict[term] + 1))  # Add 1 to avoid division by zero
        tfidf_scores[doc_id][term] = tf * idf

#tfidf_scores

# %% [markdown]
# **Store TF-IDF Scores in a DataFrame**

# %%
# Flatten the TF-IDF dictionary into a list of records
tfidf_records = []

for doc_id, terms in tfidf_scores.items():
    for term, score in terms.items():
        tfidf_records.append({'doc_id': doc_id,'term_id':vocabulary[term], 'term': term, 'tf':tf_dict[doc_id][term], 'idf':np.log(N / (df_dict[term] + 1)), 'tfidf': score})

# Create a DataFrame
tfidf_df = pd.DataFrame(tfidf_records)

# Save to CSV
tfidf_df.to_csv('tfidf_scores.csv', index=False)

tfidf_df.head()
# Out:
#    doc_id  term_id          term        tf       idf     tfidf
# 0       0     4178          mani  0.022727  2.716160  0.061731
# 1       0     7715          year  0.022727  2.509953  0.057044
# 2       0     2590        experi  0.022727  2.371001  0.053886
# 3       0     4420  michelinstar  0.022727  4.007838  0.091087
# 4       0     5826       restaur  0.068182  0.184646  0.012590

# %% [markdown]
# ##### 2.2.2 Execute the Ranked Query
# For the ranked search engine:
# - Process the query terms.
# - Use Cosine Similarity to rank matching restaurants based on the TF-IDF vectors of the query and each document.
# - Return the top-k results or all matching restaurants if fewer than k have non-zero similarity.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Function to process the input query and retrieve the top-k restaurants ranked by relevance to the query
def ranked_query(query,k):
    # Tokenize and clean the query
    query_terms = word_tokenize(preprocess_text(query))
    # Calculate the TF for each term in the query
    term_freq = Counter(query_terms)
    query_tf = {term: freq / len(query_terms) for term, freq in term_freq.items()}

    # Initialize query vector with 0s
    query_vector = np.zeros(len(tfidf_df['term_id'].unique()))  # Size based on unique terms
    # Map the query terms to their term IDs and calculate TF-IDF for each query term
    for term, tf in query_tf.items():
        if term in vocabulary:
            term_id = vocabulary[term]-1  # Get the term ID from the vocabulary
            idf_value = tfidf_df[tfidf_df['term'] == term]['idf'].iloc[0]  # Get the IDF value
            query_vector[term_id] = tf * idf_value  # Compute TF-IDF score for the query

    # Step 3: Prepare the document vectors
    # We need to create document vectors based on the tfidf_df
    doc_vectors = {}
    for doc_id in tfidf_df['doc_id'].unique():
        doc_vector = np.zeros(len(vocabulary))  # Vector for the document
        for _, row in tfidf_df[tfidf_df['doc_id'] == doc_id].iterrows():
            term_id = row['term_id']-1
            doc_vector[term_id] = row['tfidf']  # Assign the TF-IDF score for the term in the document
        doc_vectors[doc_id] = doc_vector

    # Step 4: Compute Cosine Similarity between the query and each document
    similarities = {}
    for doc_id, doc_vector in doc_vectors.items():
        cosine_sim = cosine_similarity([query_vector], [doc_vector])[0][0]
        similarities[doc_id] = cosine_sim

    # Step 5: Sort by similarity and return top-k results
    sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
    top_k_results = sorted_similarities[:k]

    results = []
    for doc_id, score in top_k_results:
        restaurant = data.iloc[doc_id]
        results.append({
        'restaurantName': restaurant['restaurantName'],
        'address': restaurant['address'],
        'description': restaurant['description'],
        'website': restaurant['website'],
        'similarity_score':score.round(4)
        })

    return  results

# %%
query = "modern seasonal cuisine"
result_query = ranked_query(query,3)
result_query
# Out:
# [{'restaurantName': 'Saur',
#   'address': 'via Filippo Turati 8',
#   'description': 'In a tiny rural village, this contemporary, almost minimalist-style restaurant serves modern cuisine with an emphasis on seasonal, regional produce.',
#   'website': 'https://ristorantesaur.it',
#   'similarity_score': np.float64(0.2428)},
#  {'restaurantName': 'La Botte',
#   'address': 'via Giuseppe Garibaldi 8',
#   'description': 'A modern and welcoming contemporary bistro situated in the heart of Stresa’s historic centre. Run by an entire family, the restaurant serves modern and imaginative fish and meat dishes where the focus is always on seasonal ingredients. The interesting wine list also includes a selection of wines by the glass.',
#   'website': 'http://www.trattorialabottestresa.it',
#   'similarity_score': np.float64(0.2325)},
#  {'restaurantName': 'Razzo',
#   'address': 'via Andrea Doria 17/f',
#   'description': 'A quiet restaurant with a relaxed, young and modern feel serving contemporary cuisine prepared from seasonal, regional products. Charming romantic outdoor area with soft lighting.',
#   'website': 'https://vadoarazzo.it/',
#   'similarity_score': np.float64(0.2246)}]

# %%
# If you prefer to visualize like this
output = pd.DataFrame(result_query)
output.head()
# Out:
#   restaurantName                   address  \
# 0           Saur      via Filippo Turati 8
# 1       La Botte  via Giuseppe Garibaldi 8
# 2          Razzo     via Andrea Doria 17/f
#
#                                          description  \
# 0  In a tiny rural village, this contemporary, al...
# 1  A modern and welcoming contemporary bistro sit...
# 2  A quiet restaurant with a relaxed, young and m...
#
#                                 website  similarity_score
# 0             https://ristorantesaur.it            0.2428
# 1  http://www.trattorialabottestresa.it            0.2325
# 2                https://vadoarazzo.it/            0.2246

# %% [markdown]
# ### **Question 3: Define a New Score!**
#
# Define the New Scoring Function: We can calculate scores based on the description, cuisine match, facilities, and price range.

# %%
def calculate_custom_score(restaurant, query, tfidf_vectorizer, tfidf_matrix):
    # Description Match Score using TF-IDF
    query_tfidf = tfidf_vectorizer.transform([query])
    description_score = (query_tfidf * tfidf_matrix[restaurant['index']].T).toarray()[0][0]

    # Cuisine Match: Simple string matching
    cuisine_score = 1 if query.lower() in restaurant['cuisineType'].lower() else 0

    # Facilities and Services: Checking for matches
    facilities = ['Terrace', 'Air conditioning']
    facilities_score = sum(1 for facility in facilities if facility.lower() in restaurant['facilitiesServices'].lower())

    # Price Range: Assigning a higher score for affordability
    price_score = 1 if restaurant['priceRange'].lower() in ['low', 'affordable'] else 0

    # Combine scores with weights
    total_score = description_score * 0.5 + cuisine_score * 0.2 + facilities_score * 0.2 + price_score * 0.1
    return total_score

# %% [markdown]
# Apply Scoring Function: Used heapq to maintain the top-k restaurants based on the scores.

# %%
def rank_restaurants(data, query):
    # Initialize TF-IDF Vectorizer and fit on restaurant descriptions
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(data['description'])

    # Create a min-heap to store the top-k restaurants
    top_k = 10
    heap = []

    for index, restaurant in data.iterrows():
        restaurant['index'] = index  # Add an index for TF-IDF scoring
        score = calculate_custom_score(restaurant, query, tfidf_vectorizer, tfidf_matrix)
        if len(heap) < top_k:
            heapq.heappush(heap, (score, restaurant))
        else:
            heapq.heappushpop(heap, (score, restaurant))

    # Sort heap by score in descending order
    ranked_restaurants = sorted(heap, key=lambda x: x[0], reverse=True)
    return [(res[1]['restaurantName'], res[1]['address'], res[1]['description'], res[1]['website'], res[0]) for res in ranked_restaurants]

# %% [markdown]
#  Output and Comparison

# %%
query = "affordable Italian restaurant with a terrace"
ranked_results = rank_restaurants(data, query)

for restaurant in ranked_results:
    print(f"Name: {restaurant[0]}, Address: {restaurant[1]}, Score: {restaurant[4]}")
# Out:
# Name: Trattoria Pomposa - Al Re gras, Address: via Castel Maraldo 57, Score: 0.48475083133133545
# Name: La Veranda, Address: via Regina 40, Score: 0.4572618026025641
# Name: Caffè Dante Bistrot, Address: piazza dei Signori 2, Score: 0.4557231924723664
# Name: ZELO, Address: via Gesù 6/8, Score: 0.45514629615116364
# Name: Locanda di Nonna Ida, Address: Località Pontarola 12, Score: 0.45225511849806865
# Name: Capogiro, Address: Località Li Mucchi Bianchi, Score: 0.4498920084616719
# Name: La Perla del Mare, Address: via della Meloria 9, Score: 0.4496610371083053
# Name: Io e Luna, Address: località Montebello 1, Score: 0.44727094626360364
# Name: Il Ristorante - Niko Romito, Address: via di Ripetta 73, Score: 0.44629988630652917
# Name: Osteria Il Cappello, Address: piazzetta Bruno Lunelli 5, Score: 0.44460824351577355

# %% [markdown]
# ### COMPARISON :
# The custom scoring function in part 3 is markedly more sophisticated and effective than the TF-IDF-only method used in part 2. By balancing textual and attribute-based matching, it significantly improves the user experience, making recommendations more aligned with practical, real-world preferences. The incorporation of factors like cuisine type, facilities, and price range allows the system to address the diverse criteria users may have when choosing a restaurant, ultimately enhancing the utility and appeal of the recommendation engine.

# %% [markdown]
# ## **Question 4**

# %% [markdown]
# The postal code is used to uniquely identify the city where the restaurant is located, with preference given to this variable over the city name, as the latter can be influenced by variations or translation issues.

# %%
combined_df[combined_df['postalCode'].isnull()]
# Out:
# Empty DataFrame
# Columns: [restaurantName, address, city, postalCode, country, priceRange, cuisineType, description, facilitiesServices, creditCards, phoneNumber, website]
# Index: []

# %% [markdown]
# No missing data, so we can proceed.

# %% [markdown]
# Starting from these postal codes, I define a function that allows me to find the coordinates, which are expressed in latitude and longitude.

# %%
# Define a function to get the coordinates (latitude and longitude) based on a postal code
def get_coordinates(postal_code):
    # Initialize the geolocator with a user-agent
    geolocator = Nominatim(user_agent="postal_code_geocoder")
    
    try:
        # Try to get the location based on the postal code and country (Italy)
        location = geolocator.geocode({'postalcode': postal_code, 'country': 'Italy'})
        
        # If a location is found, return its latitude and longitude
        if location:
            return location.latitude, location.longitude
        else:
            # Return None for both latitude and longitude if no location is found
            return None, None
    
    except Exception as e:
        # Return None for both latitude and longitude if there's an error
        return None, None

# %% [markdown]
# Using the same logic, define a function that allows me to find the region where the restaurant is located

# %%
def get_region_from_postal_code(postal_code):
    geolocator = Nominatim(user_agent="postal_code_geocoder")
    try:
        # Attempt to get the location for the given postal code and country (Italy)
        location = geolocator.geocode({'postalcode': postal_code, 'country': 'Italy'}, addressdetails=True)
        
        if location and 'address' in location.raw:
            address = location.raw['address']
            # Extract the region from the address, defaulting to 'Regione non trovata' if not found
            regione = address.get('state', 'Regione non trovata')  
            return regione
        else:
            return "Regione non trovata"
    
    except Exception as e:
        # In case of an error, return the error message
        return f"Errore: {e}"

# %% [markdown]
# I will add these additional details to the original dataset for now.

# %%
# Add new columns for latitude and longitude
combined_df['latitude'] = None
combined_df['longitude'] = None

# Iterate through each postal code to update coordinates
for idx, postal_code in tqdm(combined_df['postalCode'].items(), total=len(combined_df)):
    latitude, longitude = get_coordinates(postal_code)
    
    # Update values directly in the DataFrame
    combined_df.at[idx, 'latitude'] = latitude
    combined_df.at[idx, 'longitude'] = longitude
# Out:
# 100%|██████████| 1983/1983 [16:35<00:00,  1.99it/s]

# %%
combined_df['regione'] = combined_df['postalCode'].apply(get_region_from_postal_code)

# %%
combined_df[combined_df['regione'].isnull()]
# Out:
# Empty DataFrame
# Columns: [restaurantName, address, city, postalCode, country, priceRange, cuisineType, description, facilitiesServices, creditCards, phoneNumber, website, regione]
# Index: []

# %% [markdown]
# Additionally, I will manually specify the 4 postal codes that the function was unable to identify.

# %%
# Update the dataset for rows where the city is 'Modica'
combined_df.loc[combined_df['city'] == 'Modica', 'latitude'] = 36.8500
combined_df.loc[combined_df['city'] == 'Modica', 'longitude'] = 14.7667

combined_df.loc[combined_df['city'] == 'Syracuse', 'latitude'] = 37.0755
combined_df.loc[combined_df['city'] == 'Syracuse', 'longitude'] = 15.2866

# Update the dataset for rows where the city is 'Rotonda'
combined_df.loc[combined_df['city'] == 'Rotonda', 'latitude'] = 39.9742
combined_df.loc[combined_df['city'] == 'Rotonda', 'longitude'] = 15.7491

# Update the dataset for rows where the city is 'Castelbianco'
combined_df.loc[combined_df['city'] == 'Castelbianco', 'latitude'] = 44.1056
combined_df.loc[combined_df['city'] == 'Castelbianco', 'longitude'] = 8.0703



combined_df[combined_df['latitude'].isnull()]
# Out:
# Empty DataFrame
# Columns: [restaurantName, address, city, postalCode, country, priceRange, cuisineType, description, facilitiesServices, creditCards, phoneNumber, website, latitude, longitude, regione]
# Index: []

# %% [markdown]
# Starting from the price index expressed in '€', I will convert it into a numeric index so that operations can be performed on it.

# %%
# Define the price mapping
price_mapping = {'€': 1, '€€': 2, '€€€': 3, '€€€€': 4}

# Create a new column 'prezzi' in combined_df based on 'priceRange'
combined_df['prezzi'] = combined_df['priceRange'].replace(price_mapping)
# Out:
# C:\Users\matteo\AppData\Local\Temp\ipykernel_35716\2559523132.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_df['prezzi'] = combined_df['priceRange'].replace(price_mapping)

# %%
combined_df = pd.read_csv("combined_df.csv")

# %% [markdown]
# This is because I am creating a sub-dataset that combines the various restaurants in the same municipality for representation purposes on the map

# %%
# Aggregation based on city
aggregated_df = combined_df.groupby('city', as_index=False).agg({
    'latitude': 'first',  # Take the first latitude
    'longitude': 'first',  # Take the first longitude
    'prezzi': lambda x: round(x.mean())  # Calculate the mean of prices and round
})

# %% [markdown]
# A map has been generated using the 'folium' library. Specifically, this is an initial map that displays all the restaurants through a heatmap based on their price, as illustrated by the legend

# %%
# Create a map centered on Rome
map_obj = folium.Map(location=[41.9028, 12.4964], zoom_start=6)
map_obj.add_child(Fullscreen())

# Color mapping based on prices
color_map = {
    1: 'green',
    2: 'yellow',
    3: 'orange',
    4: 'red'
}

# Custom legend
legend_html = '''
<div style="position: fixed; 
          bottom: 50px; left: 50px; width: 150px; height: 160px; 
          background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding:10px;">
  <b>Price Legend</b><br>
  <i style="background-color: green; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €<br>
  <i style="background-color: yellow; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€<br>
  <i style="background-color: orange; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€€<br>
  <i style="background-color: red; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€€€
</div>
'''
map_obj.get_root().html.add_child(folium.Element(legend_html))

# List for heatmap data
heat_data = []

# Loop to add markers and heatmap data
for _, row in combined_df.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        # Add data for heatmap
        intensity = row['prezzi']
        normalized_intensity = {
            1: 0.2,  # Green
            2: 0.4,  # Yellow
            3: 0.7,  # Orange
            4: 1.0   # Red
        }.get(intensity, 0.1)

        heat_data.append([row['latitude'], row['longitude'], normalized_intensity])

# Add heatmap to the map
HeatMap(
    heat_data,
    radius=15,
    blur=10,
    max_zoom=1,
    gradient={0.2: 'green', 0.4: 'yellow', 0.7: 'orange', 1.0: 'red'}
).add_to(map_obj)

# Display the map
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8eea67ea3620075a31fec69ba0d8643 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#           bottom: 50px; left: 50px; width: 150px; height: 160px;
#           background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding:10px;&quot;&gt;
#   &lt;b&gt;Price Legend&lt;/b&gt;&lt;br&gt;
#   &lt;i style=&quot;background-color: green; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €&lt;br&gt;
#   &lt;i style=&quot;background-color: yellow; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€&lt;br&gt;
#   &lt;i style=&quot;background-color: orange; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€€&lt;br&gt;
#   &lt;i style=&quot;background-color: red; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€€€
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8eea67ea3620075a31fec69ba0d8643&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8eea67ea3620075a31fec69ba0d8643 = L.map(
#                 &quot;map_a8eea67ea3620075a31fec69ba0d8643&quot;,
#                 {
#                     center: [41.9028, 12.4964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_492ff747fa47754af771f31ac88b70f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_492ff747fa47754af771f31ac88b70f1.addTo(map_a8eea67ea3620075a31fec69ba0d8643);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_a8eea67ea3620075a31fec69ba0d8643);
#
#
#             var heat_map_0ece9dc4fdd985a5967538e9c8d686cc = L.heatLayer(
#                 [[44.83368337058824, 11.280355064705883, 0.4], [44.70288025244755, 8.053961726573426, 0.7], [44.348474298377035, 10.610750871036204, 0.2], [44.8323995, 12.11985473076923, 0.7], [43.79138155929032, 7.607106120580645, 0.7], [37.7041746, 15.1993938, 0.7], [45.584206767666664, 10.524267550333333, 0.7], [45.87544099473684, 11.510863021052632, 0.4], [45.63596579834906, 10.74827511981132, 0.4], [45.6081919, 7.355135857692307, 0.4], [43.95225521057692, 10.226950223076923, 0.7], [43.758065744999996, 11.236718528333332, 0.7], [37.0755, 15.2866, 0.7], [46.01303441915175, 13.334034208614977, 0.4], [44.65782313846154, 7.846317274358975, 0.4], [43.402550978206506, 13.546252900696677, 0.7], [45.72769583236994, 9.550766405202312, 0.7], [43.9086764, 12.6400739, 0.4], [40.831829368, 14.223396364, 0.2], [43.758065744999996, 11.236718528333332, 0.4], [43.25803798207547, 11.979243888679244, 0.4], [45.0118378, 9.448885433333333, 0.7], [43.31910095243902, 11.330851994794765, 0.7], [44.064358385714286, 8.203128370535715, 0.7], [43.77081693064516, 11.25933825860215, 0.2], [46.65565535, 11.178973767312643, 1.0], [38.687027472000004, 16.547051152, 0.2], [45.60207345825243, 9.742369638349516, 1.0], [44.256531894426224, 12.352149001311474, 0.4], [40.835049684090905, 14.239288841233765, 0.7], [45.9297723125, 11.9304371125, 0.4], [41.0417879, 15.784580516666665, 0.7], [41.89835487382413, 12.471791450613496, 0.7], [45.75936666578947, 7.728086236842104, 0.4], [46.69335785, 12.226781421644102, 0.7], [44.77242542, 9.39105937, 0.2], [44.338410008333334, 7.838022683333333, 0.7], [43.63732033090909, 10.292212819090908, 0.7], [43.46311977468355, 11.042788041772152, 0.7], [44.40653883483146, 11.247387434831461, 0.7], [41.272338225, 16.42290101136364, 0.4], [46.143752875, 8.466837425, 0.4], [39.22269094047619, 9.124372228571428, 0.4], [37.85174646410257, 15.285535333333334, 0.7], [46.79292465, 11.938722944164203, 1.0], [42.47906056066667, 14.198909421333333, 0.4], [42.92739725, 13.878786646208276, 0.7], [37.600136225, 12.967324658333332, 0.7], [43.84158578505636, 13.017891871916264, 0.2], [45.429807956943726, 9.07152093791086, 0.4], [44.7761276037037, 8.351724874074074, 0.2], [46.034473425, 9.12376088125, 0.7], [45.535092597499286, 9.232709261381075, 0.4], [45.45649872012336, 9.164809764996146, 0.7], [41.34185320833333, 13.410475708333333, 0.4], [45.436912568542915, 12.34291722211577, 0.7], [43.970928444827585, 12.687521348275862, 0.4], [44.23950013333333, 7.5313025, 0.7], [43

# %% [markdown]
# Once the best K restaurants are identified, their names are extracted

# %%
LISTA=[]
query = "adorable restaurant in the center of the city"
ranked_results = rank_restaurants(data, query)
for restaurant in ranked_results:
    LISTA.append(restaurant[0])

# %% [markdown]
# A second map is generated, showing only the restaurants selected from the search. In this case, they are represented with points on the map.

# %%
# Filter new_df to select only rows where "risto" is present in the list
filtered_df = combined_df[combined_df['restaurantName'].isin(LISTA)]

# Aggregation based on city for the filtered DataFrame
aggregated_df = filtered_df.groupby('city', as_index=False).agg({
    'latitude': 'first',  # Take the first latitude
    'longitude': 'first',  # Take the first longitude
    'postalCode': 'first',  # Take the first postal code
    'regione': 'first',  # Take the first region
    'prezzi': lambda x: round(x.mean()),  # Calculate the mean of prices and round
    'restaurantName': 'count'  # Count the number of restaurants in the city
})


# Create the map
map_obj = folium.Map(location=[41.9028, 12.4964], zoom_start=6)
map_obj.add_child(Fullscreen())

# Color map for prices
color_map = {
    1: 'green',
    2: 'yellow',
    3: 'orange',
    4: 'red'
}

# Add legend to the map
legend_html = '''
<div style="position: fixed; 
          bottom: 50px; left: 50px; width: 150px; height: 160px; 
          background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding:10px;">
  <b>Price Legend</b><br>
  <i style="background-color: green; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €<br>
  <i style="background-color: yellow; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€<br>
  <i style="background-color: orange; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€€<br>
  <i style="background-color: red; width: 20px; height: 20px; display: inline-block; margin-right: 5px;"></i> €€€€
</div>
'''
# Add legend to the map
map_obj.get_root().html.add_child(folium.Element(legend_html))

for _, row in aggregated_df.iterrows():
    color = color_map.get(row['prezzi'], 'blue')  # Color based on price

    # Description for the marker tooltip
    description = f"City: {row['city']}, Region: {row['regione']}, Restaurants: {row['restaurantName']}"

    # Add marker to the map
    Marker(
        location=(row['latitude'], row['longitude']),
        tooltip=description,
        icon=folium.Icon(color=color)
    ).add_to(map_obj)

# Display the map
map_obj
# Out:
# C:\Users\matteo\AppData\Local\Temp\ipykernel_25768\1958449040.py:52: UserWarning: color argument of Icon should be one of: {'orange', 'purple', 'gray', 'darkred', 'pink', 'red', 'lightgreen', 'blue', 'cadetblue', 'green', 'white', 'lightred', 'darkpurple', 'darkblue', 'beige', 'lightgray', 'lightblue', 'darkgreen', 'black'}.
#   icon=folium.Icon(color=color)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a92a1737c3720e84286de3a2ce172713 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#           bottom: 50px; left: 50px; width: 150px; height: 160px;
#           background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding:10px;&quot;&gt;
#   &lt;b&gt;Price Legend&lt;/b&gt;&lt;br&gt;
#   &lt;i style=&quot;background-color: green; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €&lt;br&gt;
#   &lt;i style=&quot;background-color: yellow; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€&lt;br&gt;
#   &lt;i style=&quot;background-color: orange; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€€&lt;br&gt;
#   &lt;i style=&quot;background-color: red; width: 20px; height: 20px; display: inline-block; margin-right: 5px;&quot;&gt;&lt;/i&gt; €€€€
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a92a1737c3720e84286de3a2ce172713&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a92a1737c3720e84286de3a2ce172713 = L.map(
#                 &quot;map_a92a1737c3720e84286de3a2ce172713&quot;,
#                 {
#                     center: [41.9028, 12.4964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d89bdee5831c8f907bb849b282f77ee7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d89bdee5831c8f907bb849b282f77ee7.addTo(map_a92a1737c3720e84286de3a2ce172713);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_a92a1737c3720e84286de3a2ce172713);
#
#
#             var marker_9c6eacdbaf7c39aacbf8b4cf0643c765 = L.marker(
#                 [43.46583124588689, 11.868504568123392],
#                 {}
#             ).addTo(map_a92a1737c3720e84286de3a2ce172713);
#
#
#             var icon_2f1ab88375e478689a600f1295d57627 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c6eacdbaf7c39aacbf8b4cf0643c765.setIcon(icon_2f1ab88375e478689a600f1295d57627);
#
#
#             marker_9c6eacdbaf7c39aacbf8b4cf0643c765.bindTooltip(
#                 `&lt;div&gt;
#                      City: Arezzo, Region: Toscana, Restaurants: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5bfbc2a690463705172c02efeff40dea = L.marker(
#                 [44.49182438639004, 11.336281052614108],
#                 {}
#             ).addTo(map_a92a1737c3720e84286de3a2ce172713);
#
#
#             var icon_513f808b3b89e5fdf2af7d07e8763fed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5bfbc2a690463705172c02efeff40dea.setIcon(icon_513f808b3b89e5fdf2af7d07e8763fed);
#
#
#             marker_5bfbc2a690463705172c02efeff40dea.bindTooltip(
#                 `&lt;div&gt;
#                      City: Bologna, Region: Emilia-Romagna, Restaurants: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a1466f8ff308a066eaa2295c305294a = L.marker(
#                 [37.4306822, 15.01951223208872],
#                 {}
#             ).addTo(map_a92a1737c3720e84286de3a2ce172713);
#
#
#             var icon_8d7c6484ddfcc273725f5ece95c4d768 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a1466f8ff308a066eaa2295c305294a.setIcon(icon_8d7c6484ddfcc273725f5ece95c4d768);
#
#
#             marker_8a1466f8ff308a066eaa2295c305294a.bindTooltip(
#                 `&lt;div&gt;
#                      City: Catania, Region: Sicilia, Restaurants: 1
#                  &lt;/div&gt;`,

# %% [markdown]
# ## 5. BONUS: Advanced Search Engine

# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import HTML
import pandas as pd

# %%
merged_data = pd.read_csv("merged_data.csv")
merged_data = merged_data.fillna('')
#merged_data.isnull().sum()

# %% [markdown]
# #### Build inverted indexes for restaurantName, city and cuisineType

# %%
import re
from collections import defaultdict

# Inverted index for restaurantName
inverted_index_rest = defaultdict(list)
for doc_id, rest in enumerate(merged_data['restaurantName'], start=0):
    words_in_rest = set(re.findall(r'\b\w+\b', rest.lower()))  # Get unique words in the description
    for word in words_in_rest:
        inverted_index_rest[word].append(doc_id)

# Inverted index for city
inverted_index_city = defaultdict(list)
for doc_id, c in enumerate(merged_data['city'], start=0):
    words_in_c = set(re.findall(r'\b\w+\b', c.lower()))  # Get unique words in the description
    for word in words_in_c:
        inverted_index_city[word].append(doc_id)

# Inverted index for cuisine
inverted_index_cuisine = defaultdict(list)
for doc_id, cuisine in enumerate(merged_data['cuisineType'], start=0):
    words_in_c = set(re.findall(r'\b\w+\b', cuisine.lower()))  # Get unique words in the description
    for word in words_in_c:
        inverted_index_cuisine[word].append(doc_id)

# %%
unique_creditCards = set()
for i in list(merged_data["creditCards"].unique()):
    single_creditcard = i.split('|')
    for x in single_creditcard:
        if x !='':
            unique_creditCards.add(x)
#unique_creditCards

facilitiesoptions = set()
for i in list(merged_data["facilitiesServices"].unique()):
    single_creditcard = i.split('|')
    for x in single_creditcard:
        if x !='':
            facilitiesoptions.add(x)
#facilitiesoptions

filtered_regions = merged_data["regione"].unique()
filtered_regions = [region for region in filtered_regions if region != "Regione non trovata"]

# %%
def advanced_search_engine(query):
        query_terms = query.lower().split()
        matched_restaurants = set()  # Collect matched restaurant IDs
        scores = {}  # Collect scores for matched restaurants

        for term in query_terms:
            # Match against restaurantName
            if term in inverted_index_rest:
                for rest_id in inverted_index_rest[term]:
                    matched_restaurants.add(rest_id)
                    scores[rest_id] = scores.get(rest_id, 0) + 3  # Weight = 3

            # Match against city
            if term in inverted_index_city:
                for rest_id in inverted_index_city[term]:
                    matched_restaurants.add(rest_id)
                    scores[rest_id] = scores.get(rest_id, 0) + 2  # Weight = 2

            # Match against cuisineType
            if term in inverted_index_cuisine:
                for rest_id in inverted_index_cuisine[term]:
                    matched_restaurants.add(rest_id)
                    scores[rest_id] = scores.get(rest_id, 0) + 1  # Weight = 1

        # Retain scores for filtered restaurants
        final_restaurants = [(rest_id, scores[rest_id]) for rest_id in matched_restaurants]

        # Sort by score (if needed)
        final_restaurants = sorted(final_restaurants, key=lambda x: x[1], reverse=True)
        return final_restaurants

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Restaurant Name Input
name_rest = widgets.Text(
    value='',
    placeholder='Type something',
    description='Restaurant:',
    disabled=False   
)

# City Name Input
name_city = widgets.Text(
    value='',
    placeholder='Type something',
    description='City:',
    disabled=False   
)

# Cuisine Type Input
name_cuisine = widgets.Text(
    value='',
    placeholder='Type something',
    description='Cuisine:',
    disabled=False   
)

# Price Range Slider
price_slider = widgets.SelectionRangeSlider(
    options=["€", "€€", "€€€", "€€€€"],
    index=(0, 3),
    description='Price Range',
    disabled=False
)

# Capture Price Range
def on_value_change(change):
    global selected_min_price, selected_max_price
    selected_min_price, selected_max_price = change['new']

price_slider.observe(on_value_change, names='value')


# Create Checkbox Grid
def create_checkbox_grid(options, num_columns):
    checkboxes = [widgets.Checkbox(value=False, description=opt) for opt in options]
    grid = widgets.GridBox(
        children=checkboxes,
        layout=widgets.Layout(
            grid_template_columns=f'repeat({num_columns}, 200px)',  
            grid_gap='10px',
        )
    )
    return checkboxes, grid

# Generate Grids for Credit Cards and Facilities
region_checkboxes, region_grid = create_checkbox_grid(filtered_regions, 3)
credit_card_checkboxes, credit_card_grid = create_checkbox_grid(unique_creditCards, 2)
facilities_checkboxes, facilities_grid = create_checkbox_grid(facilitiesoptions, 2)

# Get Selected Options
def get_selected_options(checkboxes):
    return [cb.description for cb in checkboxes if cb.value]

# Submit Button
button = widgets.Button(description="Search")

# Output Widget
output = widgets.Output()

# Handle Button Click
def on_button_click(b):
    with output:
        clear_output()
        selected_restaurant = name_rest.value.strip()
        selected_city = name_city.value.strip()
        selected_cuisine = name_cuisine.value.strip()
        selected_price_range = (selected_min_price, selected_max_price)
        selected_regions = get_selected_options(region_checkboxes)
        selected_credit_cards = get_selected_options(credit_card_checkboxes)
        selected_facilities = get_selected_options(facilities_checkboxes)
        query1 = selected_restaurant+' '+selected_city+' '+selected_cuisine

        output_query = advanced_search_engine(query1)
        filtered_restaurants = []
        for rest_id, score in output_query:
        # Retrieve row merged_data for the restaurant
            row = merged_data.iloc[rest_id]
            reg = row['regione']

            if reg not in selected_regions:
                continue
            
            # Check if the price in row falls within the selected price range
            if not (selected_min_price.count('€') <= row["priceRange"].count('€') <= selected_max_price.count('€')):
                continue
            
            # Check if all selected credit cards are present in the row's credit cards
            credit_cards = set(row["creditCards"].split('|'))
            if not all(card in credit_cards for card in selected_credit_cards):
                continue
            
            # Check if all selected facilities are present in the row's facilities
            facilities = set(row["facilitiesServices"].split('|'))
            if not all(facility in facilities for facility in selected_facilities):
                continue
            
            # If all conditions are satisfied, add the restaurant to the filtered list
            filtered_restaurants.append(rest_id)
        for r_id in filtered_restaurants:
            print("Restaurant Name: ", merged_data['restaurantName'].iloc[r_id])
            print("Address: ", merged_data['address'].iloc[r_id])
            print("Cuisine Type: ", merged_data['cuisineType'].iloc[r_id])
            print("Price Range: ", merged_data['priceRange'].iloc[r_id])
            print("Website: ", merged_data['website'].iloc[r_id])

button.on_click(on_button_click)

# %%
from ipywidgets import VBox, HBox, Label, Accordion, Layout

# Search Criteria Section
search_criteria_box = VBox(
    [
        Label("Search Criteria", style={"font-weight": "bold", "font-size": "16px"}),
        name_rest,
        name_city,
        name_cuisine,
        price_slider,
    ],
    layout=Layout(padding="10px", border="1px solid black", margin="10px")
)

# Filters Section
filters_box = VBox(
    [
        Label("Filter Options", style={"font-weight": "bold", "font-size": "16px"}),
        Label("Region:"),
        region_grid,
        Label("Accepted Credit Cards:"),
        credit_card_grid,
        Label("Facilities:"),
        facilities_grid,
    ],
    layout=Layout(padding="10px", border="1px solid black", margin="10px")
)

# Collapsible Filters
accordion = Accordion(
    children=[filters_box],
    titles=("Filters",),
    layout=Layout(margin="10px")
)
accordion.set_title(0, "Filter Options")

# Submit Section
submit_section = VBox(
    [button],
    layout=Layout(padding="10px", margin="10px", justify_content="center")
)

# Output Section
output_section = VBox(
    [output],
    layout=Layout(padding="10px", border="1px solid black", margin="10px")
)

# Full Layout
layout = VBox(
    [
        search_criteria_box,
        accordion,
        submit_section,
        output_section
    ],
    layout=Layout(padding="10px", margin="20px")
)

# Display the Interface
display(layout)
# Out:
# VBox(children=(VBox(children=(Label(value='Search Criteria'), Text(value='', description='Restaurant:', placeh…

# %% [markdown]
# # ALGORİTHMİC QUESTİON

# %% [markdown]
# 1.
#
# Input: t - number of test cases
#
# For each test case:
#     1. Read n - number of packages.
#     2. Initialize an empty list `packages`.
#     3. For each package (i from 1 to n):
#        - Read coordinates (x_i, y_i) and add (x_i, y_i) to `packages`.
#     4. Sort `packages` by x-coordinate, then by y-coordinate.
#
#     5. Initialize current position as (0, 0).
#     6. Initialize an empty string `path`.
#     7. Set `possible` to True.
#
#     8. For each package in sorted `packages`:
#        - Calculate the horizontal moves required to reach the package's x-coordinate from the current x-coordinate.
#        - Calculate the vertical moves required to reach the package's y-coordinate from the current y-coordinate.
#        - If the target x-coordinate is less than the current x-coordinate or
#          the target y-coordinate is less than the current y-coordinate:
#            - Set `possible` to False and break the loop (the package is unreachable).
#        - Otherwise:
#            - Append 'R' repeated (target x - current x) times to `path` for right moves.
#            - Append 'U' repeated (target y - current y) times to `path` for up moves.
#            - Update current position to the package's coordinates.
#
#     9. If `possible` is True:
#        - Append "YES" and `path` to the output.
#     10. If `possible` is False:
#        - Append "NO" to the output.
#
# Output: For each test case, print "YES" and the path if possible, or "NO" if not.

# %%
# Get all input at once
input_data = input("Enter the input: ").splitlines()  # Girdiyi bir seferde al ve satır satır ayır

# Parse the number of test cases
t = int(input_data[0])  # İlk satır test vaka sayısı

index = 1  # Başlangıç indexi

# For each test case
for _ in range(t):
    # Read the number of packages
    n = int(input_data[index])  # Paket sayısını oku
    index += 1
    
    packages = []
    
    # Read the coordinates of each package
    for _ in range(n):
        x, y = map(int, input_data[index].split())  # Her paketin koordinatlarını oku
        packages.append((x, y))
        index += 1
    
    # Sort the packages by x and y coordinates
    packages.sort()  # Paketleri x ve y koordinatlarına göre sırala
    
    # Initialize starting position and other variables
    current_x, current_y = 0, 0
    path = ""
    possible = True
    
    # Iterate over sorted packages
    for x, y in packages:
        # Check if package is reachable
        if x < current_x or y < current_y:
            possible = False
            break
        else:
            # Add right movements ('R') to the path string
            path += 'R' * (x - current_x)
            # Add up movements ('U') to the path string
            path += 'U' * (y - current_y)
            # Update the current position
            current_x, current_y = x, y
    
    # Output result
    if possible:
        print("YES")
        print(path)
    else:
        print("NO")
# Out:
# YES
# RUUURRRRUU
# NO
# YES
# RRRRUUU

# %% [markdown]
# 3.
# To analyze the time complexity of this algorithm, let’s break down each step and calculate its complexity. This will allow us to express the total complexity in Big-O notation.
#
# Step-by-Step Analysis and Time Complexity
#
# 	1.	Input Reading:
# 	•	The algorithm reads the number of test cases, t, and for each test case, it reads the coordinates of n packages.
# 	•	Reading the input for n packages takes O(n) time per test case. With t test cases, this step contributes O(n) time for each case.
# 	2.	Sorting Step:
# 	•	The packages are sorted based on their  (x, y)  coordinates, which typically takes O(n \log n) time.
# 	•	Since sorting is the most time-consuming step in the algorithm, it contributes the largest portion of the time complexity. As n grows, this sorting step scales with O(n \log n).
# 	3.	Path Construction:
# 	•	After sorting, the algorithm iterates over each package, calculates the necessary right (R) and up (U) moves, and appends them to the path string.
# 	•	This step takes O(n) time, as each package is processed once.
# 	4.	Generating Output:
# 	•	Finally, the algorithm prints “YES” or “NO” and the path string for each test case.
# 	•	Output generation takes O(n) time because the path string is built based on the coordinates of the n packages.
#
# Overall Time Complexity
#
# Since sorting is the most time-intensive step for each test case, the total time complexity for a single test case is O(n \log n).
#
# With t test cases, the overall time complexity becomes:
#
#
# O(t \cdot n \log n)
#
#
# Steps Contributing Most to Complexity
#
# 	1.	Sorting Step (O(n \log n)): Sorting the packages by x and y coordinates is the primary contributor to the algorithm’s time complexity because, as n increases, the additional  \log n  factor from sorting has a significant impact.
# 	2.	Path Construction Step (O(n)): Calculating the movements and constructing the path string takes O(n) time, but its impact is smaller compared to sorting.
#
# Therefore, the overall time complexity of the algorithm is O(t \cdot n \log n), with the sorting step being the dominant factor.

# %% [markdown]
# 4.  Assessment of Time Complexity Using LLM
#  If we were to ask  CLAUDE  to evaluate the time complexity,
#
# Let's analyze the main parts of the code:
#
# Input handling and parsing:
# O(1) - constant time
#
# For each test case:
#
# Reading coordinates for n packages: O(n)
# Sorting packages: O(n log n)
# Creating route for each package (inner loop): O(n)
#
# Overall time complexity analysis:
#
# For each test case, the dominant term is O(n log n) due to the sorting operation
# With t test cases, the total complexity is: O(t * n log n)
#
# This assessment is accurate because:
#
# Python's sort() method uses TimSort algorithm which has O(n log n) complexity
# Other operations (route creation, coordinate reading) are O(n)
# Since O(n log n) > O(n), the dominant term for each test case is O(n log n)
#
# In worst-case scenario:
#
# Route calculation for each package: O(n)
# Sorting operation: O(n log n)
# t test cases: O(t)
#
# Therefore, O(t * n log n) is the correct time complexity.
# Potential improvement:
#
# If the order of packages input doesn't matter specifically, removing the sorting operation could reduce the complexity to O(t * n).

# %% [markdown]
# 5.
# The greedy algorithm, which directs the robot to the closest package from its current location, is not necessarily optimal in terms of minimizing the total distance traveled. While it may seem intuitive to go to the closest package first, this approach does not guarantee the shortest possible total path. Here’s why:
#
# Counterexample Showing the Greedy Algorithm is Not Optimal
#
# Consider the following setup:
# 	1.	Robot starting position: (0, 0)
# 	2.	Package locations:
# 	•	Package 1 at (3, 0)
# 	•	Package 2 at (3, 3)
# 	•	Package 3 at (0, 3)
#
# Greedy Approach (Closest-First)
#
# Using the greedy approach, the robot will:
# 	1.	Move from (0, 0) to the closest package, Package 1 at (3, 0), traveling a distance of 3.
# 	2.	From (3, 0), the closest package is Package 2 at (3, 3), traveling an additional distance of 3.
# 	3.	From (3, 3), the last package (Package 3 at (0, 3)) is reached, traveling another distance of 3.
#
# The total distance traveled using the greedy approach is 3 + 3 + 3 = 9.
#
# Optimal Approach
#
# To minimize the total distance, a better approach would be:
# 	1.	Move from (0, 0) to Package 3 at (0, 3), traveling a distance of 3.
# 	2.	From (0, 3), move to Package 2 at (3, 3), traveling an additional distance of 3.
# 	3.	From (3, 3), move to Package 1 at (3, 0), traveling a distance of 3.
#
# The total distance traveled with this order is also 3 + 3 + 3 = 9.
#
# However, in cases where there are more than three points or different orientations, such as a zigzag or non-straight path, this can be suboptimal
